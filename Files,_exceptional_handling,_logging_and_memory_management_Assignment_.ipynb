# %% [markdown]
# #**Files, exceptional handling, logging and memory management Assignment**

# %% [markdown]
# #**Theoty Questions**

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?

# %% [markdown]
# Ans. 1. Compiled Languages
# * A compiler translates the entire source code into machine code before the program runs.
#
# * The result is a standalone executable file (e.g., .exe in Windows).
#
# * Faster execution, since the translation is already done.
#
# * Examples: C, C++, Rust, Go
#
# 2.  Interpreted Languages
# * An interpreter reads and executes the code line by line at runtime.
#
# * No separate executable is produced; code runs directly using the interpreter.
#
# * Slower execution, but faster development.
#
# * Examples: Python, JavaScript, Ruby, PHP

# %% [markdown]
# 2. What is exception handling in Python?

# %% [markdown]
# Ans. Exception handling in Python is a mechanism that lets you gracefully handle errors during program execution instead of letting the program crash.
#
# When something goes wrong (like dividing by zero or trying to open a missing file), Python raises an exception. You can catch and handle these exceptions using try, except, and optionally finally or else.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?

# %% [markdown]
# Ans. The finally block is used to define code that must be executed, no matter what — whether an exception was raised or not.
#
# Key Purposes of finally:
# 1. Cleanup actions:
#
# * Closing files
#
# * Releasing resources (e.g., database connections, network sockets)
#
# * Rolling back transactions
#
# 2. Ensures reliability:
#
# * Guarantees that certain essential code runs, even if an error occurs or the user interrupts the program.

# %% [markdown]
# 4. What is logging in Python?

# %% [markdown]
# Ans. Logging in Python is the process of recording messages that describe events happening while a program runs. It helps developers:
#
# * Track errors
#
# * Debug code
#
# * Monitor execution flow
#
# * Record system activity
#
# Instead of using print() statements, Python provides the built-in logging module, which is more flexible and powerful.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python?

# %% [markdown]
# Ans. The __del__ method is a special method in Python, known as a destructor. It is called automatically when an object is about to be destroyed — usually when it goes out of scope or is deleted with del.

# %% [markdown]
# 6.  What is the difference between import and from ... import in Python?

# %% [markdown]
# Ans. Both are used to bring modules or specific components into your Python code, but they differ in how they import and what you access afterward.
# 1. import module
# * This imports the entire module, and you access its contents using dot notation.
#
# 2. from module import something
# * This imports a specific attribute (function, class, variable) from a module directly.
#
# 3. from module import
# * This imports everything from a module into the current namespace.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?

# %% [markdown]
# Ans.
# 1. Multiple except blocks (recommended)
# * You can write separate blocks to handle different types of exceptions.
#
# 2. Single except block with multiple exceptions (tuple)
# * Use this when you want to handle multiple exceptions the same way.
# 3. Catch All Exceptions (Generic Catch)
# * You can catch any exception using except Exception as e. This is useful for logging or fallback behavior, but should be used with care.
# 4. Using else and finally with multiple exceptions

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python?

# %% [markdown]
# Ans. The with statement is used to open and manage files safely and efficiently in Python. It ensures that resources like files are properly closed after their use — even if an error occurs during processing.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?

# %% [markdown]
# Ans.  1. Multithreading
# * Runs multiple threads within a single process.
#
# * Threads share the same memory space.
#
# * Useful for I/O-bound tasks (e.g., file reading, web requests).
# 2. Multiprocessing
# * Runs multiple processes, each with its own memory space.
#
# * Suitable for CPU-bound tasks (e.g., calculations, image processing).
#
# * Bypasses Python’s GIL — can use multiple CPU cores.

# %% [markdown]
# 10. What are the advantages of using logging in a program?

# %% [markdown]
# Ans.  Advantages of Using Logging in a Python Program
#
# Using the built-in logging module provides many benefits over simple print() statements, especially in real-world and production-level applications.
#
# 1. Tracks Program Execution
# * Logs help you understand what the program is doing step by step.
# * Useful for debugging and analyzing behavior after something goes wrong.
#
# 2. Error Detection and Debugging
# * Logs help you detect issues and understand why an error occurred, even after the program has finished running.
# 3. Different Logging Levels
# * Allows you to categorize messages by importance:
# * DEBUG, INFO, WARNING, ERROR, CRITICAL
#
# 4. Avoids Clutter in Production
# * You can turn off or filter debug-level logs in production by changing the logging level.
# * This keeps logs relevant and avoids showing unnecessary output to end-users.
#
# 5. Logs to Files or External Systems
# * Supports logging to files, network servers, or external tools (like Logstash, Sentry).
# * Useful for monitoring and long-term storage.
# 6. Thread- and Process-safe
# * Logging is designed to work correctly in multi-threaded and multi-process programs without conflict.
# 7. Structured, Configurable Output
# * Supports custom formats:
#  * Timestamps
#  * Log levels
#  * Function names
#  * Line numbers
#
# 8. Easier Maintenance and Monitoring
# * Logs provide a historical record of how the software behaves.
# * Helps in maintaining, auditing, and troubleshooting large applications.

# %% [markdown]
# 11. What is memory management in Python?

# %% [markdown]
# Ans. Memory management in Python refers to the process of allocating, using, and releasing memory during the execution of a program.
#
# Python handles most memory operations automatically, thanks to its built-in memory manager and garbage collector.

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python?

# %% [markdown]
# Ans. Exception handling in Python follows a structured approach to detect, respond to, and recover from errors that occur during program execution.
#
# Here are the basic steps involved:
#
# 1. Try Block - Detect the Error
# * Wrap the code that might raise an exception in a try block.
#
# 2. Except Block - Handle the Error
# * Define how to respond to specific exceptions using except.
#
# 3. Else Block (Optional) - Code if No Exception
# * Use else to run code only if no exception occurred in the try block.
#
# 4. Finally Block (Optional) - Cleanup Code
# * Use finally to define code that runs no matter what — whether an exception occurred or not.

# %% [markdown]
# 13. Why is memory management important in Python?

# %% [markdown]
# Ans. Memory management is crucial in Python (and all programming) because it directly affects your program’s:
#
# * Performance
#
# * Stability
#
# *  Scalability
#
# *  Resource usage
# 1. Ensures Efficient Resource Use
# * Python applications run on devices with limited memory (RAM). Good memory management ensures:
#
# * No memory is wasted
#
# * Your program runs efficiently
#
# * Other processes aren’t starved of memory
#
# 2. Prevents Memory Leaks
# * If unused objects are not cleared, memory keeps filling up, which leads to:
#
# * Slower performance
#
# * Crashes
#
# * Out-of-memory errors
#
# * Python’s garbage collector helps prevent this by reclaiming memory from unreferenced objects.
#
# 3. Supports Long-Running Programs
# * Programs like web servers or background services may run for days or months. Without proper memory management:
#
# * Memory usage can grow uncontrollably over time
#
# * System performance will degrade
#
# 4. Improves Performance
# *  By managing memory smartly (e.g., using generators instead of loading everything into lists), you:
#
# * Reduce memory usage
#
# * Speed up execution
#
# * Avoid swapping to disk
#
# 5. Prevents Crashes and Bugs
# * Poor memory handling can cause:
#
# * Crashes from too much memory usage
#
# * Hard-to-debug issues (e.g., dangling references or memory corruption)

# %% [markdown]
# 14. What is the role of try and except in exception handling?

# %% [markdown]
# Ans. The try and except blocks are the core tools used in Python to handle exceptions — errors that occur during program execution.
#
# 1. try Block — Detect Errors
# * The try block contains the code that might cause an exception.
# * If an error occurs inside the try block, Python jumps to the matching except block.
#
# 2. except Block — Handle Errors
# * The except block catches and handles exceptions that occurred in the try block.
# * It prevents the program from crashing and lets you respond gracefully.

# %% [markdown]
# 15.  How does Python's garbage collection system work?

# %% [markdown]
# Ans. Python's garbage collection (GC) system is responsible for automatically reclaiming memory by destroying objects that are no longer needed, helping you avoid memory leaks and manual cleanup.

# %% [markdown]
# 16. What is the purpose of the else block in exception handling?

# %% [markdown]
# Ans. The else block in Python exception handling is used to define code that should run only if no exception occurs in the try block.
#
#
# * To separate the success logic from the error handling
#
# * Improves code readability and clarity
#
# * Helps avoid placing non-error-related code in the try block unnecessarily

# %% [markdown]
# 17. What are the common logging levels in Python?

# %% [markdown]
# Ans. Python’s built-in logging module provides five standard logging levels, each indicating the severity or importance of the message being logged.
#
# * DEBUG	- Detailed info, useful for debugging during development
# * INFO	- General info about program execution (e.g., "Process started")
# * WARNING	- Something unexpected happened, but the program still works
# * ERROR	- A serious problem occurred, affecting functionality
# * CRITICAL	- A severe error — program may crash or is in danger

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python?

# %% [markdown]
# Ans. 1. os.fork()
#
# * os.fork() creates a child process by duplicating the current process.
#
# * The new (child) process gets a copy of the parent’s memory.
#
# * It’s a low-level system call available only on UNIX-like systems (Linux, macOS).
#
# 2. multiprocessing Module
#
# * Provides a high-level API to create and manage separate processes.
#
# * Works on all platforms (including Windows).
#
# * Bypasses the GIL (Global Interpreter Lock), so great for CPU-bound tasks.

# %% [markdown]
# 19. What is the importance of closing a file in Python?

# %% [markdown]
# Ans. 1. Frees Up System Resources
# * Each open file consumes system resources (like file descriptors).
#
# * If too many files are left open, your system may run out of available resources.
#
# 2. Flushes Data to Disk
# * When writing to a file, data may be buffered (held temporarily in memory).
#
# * Closing the file ensures all buffered data is written to the disk properly.
#
# 3. Prevents Data Corruption
# * Not closing files properly (especially in write mode) can lead to:
# * Incomplete writes
# * Corrupt files
# * Loss of important data
#
# 4. Avoids File Locks and Access Issues
# * Some systems lock files while they’re open.
# * If a file isn't closed, other programs might not be able to read or write to it.
#
# 5. Cleaner and Safer Code
# * Closing files manually or using with statements prevents accidental bugs and improves code quality.

# %% [markdown]
# 20. What is the difference between file.read() and file.readline() in Python?

# %% [markdown]
# Ans. 1. file.read()
# * Reads the entire file content (or a specified number of bytes) into a single string.
#
# * Consumes the whole file at once (unless size is specified).
#
# 2. file.readline()
# * Reads only one line at a time from the file.
# * Useful for line-by-line processing (e.g., logs or large files).

# %% [markdown]
# 21.  What is the logging module in Python used for?

# %% [markdown]
# Ans. The logging module in Python is used for tracking events that happen during the execution of a program. It allows developers to record:
# * Informational messages
# * Warnings
# * Errors
# * Debugging data
# * Critical failures

# %% [markdown]
# 22. What is the os module in Python used for in file handling?

# %% [markdown]
# Ans. The os module in Python provides functions to interact with the operating system, especially for tasks like file and directory handling. It allows you to work with the file system in a platform-independent way.

# %% [markdown]
# 23.  What are the challenges associated with memory management in Python?

# %% [markdown]
# While Python handles most memory tasks automatically (thanks to its built-in garbage collector and reference counting), there are still several challenges and limitations that developers should be aware of.
#
# 1. Reference Cycles
# * Python uses reference counting, but objects that reference each other (circular references) can avoid cleanup.
# * Python’s garbage collector handles cycles, but it may not collect them immediately or efficiently.
# 2. Memory Leaks
# * Even in a garbage-collected language like Python, memory leaks can occur when:
# * Global variables or containers hold references longer than needed
# * C extensions or libraries improperly manage memory
# * Closures and decorators retain references
# 3. High Memory Usage with Large Data
# * Python objects are not memory-efficient by default. Lists, dictionaries, and objects consume more memory compared to lower-level languages.
# 4. Global Interpreter Lock (GIL)
# * Python’s GIL prevents true multithreaded parallelism in CPython.
#
# * Even if multiple threads run, only one thread executes Python bytecode at a time.
# * This limits performance on multi-core CPUs for CPU-bound tasks.
# 5. Unpredictable Garbage Collection Timing
# * Python's garbage collector runs automatically, but not at predictable intervals.
# * If your program uses large objects or handles many temporary objects, you may experience spikes in memory usage.
# 6. Memory Fragmentation
# * Python allocates small objects using a system called pymalloc.
# * Over time, memory may become fragmented, leading to inefficient usage, especially in long-running applications.
# 7. Hidden Object References
# * Sometimes, references are maintained implicitly by:
#  * Closures
#  *  Exception tracebacks
#  * Caches (like lru_cache, functools)
#  * Logger or event handlers

# %% [markdown]
# 24. How do you raise an exception manually in Python?

# %% [markdown]
# Ans. In Python, you can manually raise an exception using the raise statement. This is useful when you want to enforce rules, signal an error, or handle unexpected situations in your code.

# %% [markdown]
# 25. Why is it important to use multithreading in certain applications?

# %% [markdown]
# Ans. Multithreading is important in applications where you want to perform multiple tasks concurrently without waiting for one to finish before starting another — especially when tasks involve I/O operations (input/output), like reading from a file, accessing a database, or waiting for network responses.

# %% [markdown]
# #**Practical Questions**

# %% [markdown]
# 1.  How can you open a file for writing in Python and write a string to it?

# %%
with open("output.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, this is a string written to the file.

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line.

# %%
with open("/content/LINE.TEX.txt", "r") as file:
    # Read and print each line one by one
    for line in file:
        print(line, end="")
# Out:
# Line 1: Hello
# Line 2: Welcome to Python
# Line 3: File reading example

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
filename = "nonexistent.txt"

try:
    with open(filename, "r") as file:
        for line in file:
            print(line, end="")
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Error: The file 'nonexistent.txt' does not exist.

# %% [markdown]
# 4.  Write a Python script that reads from one file and writes its content to another file.

# %%
# Define the source and destination file names
source_file = "/content/LINE.TEX.txt"
destination_file = "destination.txt"

try:
    # Open the source file in read mode
    with open(source_file, "r") as src:
        # Open the destination file in write mode
        with open(destination_file, "w") as dest:
            # Read each line from source and write to destination
            for line in src:
                dest.write(line)

    print(f"Contents copied from '{source_file}' to '{destination_file}' successfully.")

except FileNotFoundError:
    print(f"Error: The file '{source_file}' does not exist.")
# Out:
# Contents copied from '/content/LINE.TEX.txt' to 'destination.txt' successfully.

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Cannot divide by zero.

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging

# Configure logging to write to a file
logging.basicConfig(filename="error.log", level=logging.ERROR,
                    format="%(asctime)s - %(levelname)s - %(message)s")

try:
    # Code that may raise a division by zero error
    a = 10
    b = 0
    result = a / b
except ZeroDivisionError as e:
    logging.error("Attempted to divide by zero: %s", e)
    print("Error occurred. Check 'error.log' for details.")
# Out:
# ERROR:root:Attempted to divide by zero: division by zero
# Error occurred. Check 'error.log' for details.

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

# Configure logging
logging.basicConfig(
    filename="app.log",         # Log file name
    level=logging.DEBUG,        # Minimum level to log
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Log messages at different severity levels
logging.debug("This is a DEBUG message (used for diagnostics).")
logging.info("This is an INFO message (general information).")
logging.warning("This is a WARNING message (something unexpected).")
logging.error("This is an ERROR message (a failure in a function).")
logging.critical("This is a CRITICAL message (serious error).")
# Out:
# WARNING:root:This is a WARNING message (something unexpected).
# ERROR:root:This is an ERROR message (a failure in a function).
# CRITICAL:root:This is a CRITICAL message (serious error).

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling.

# %%
filename = "missing_file.txt"

try:
    # Attempt to open the file in read mode
    with open(filename, "r") as file:
        content = file.read()
        print("File content:")
        print(content)

except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
# Out:
# Error: The file 'missing_file.txt' was not found.

# %%
#2nd example
filename = "/content/output.txt"

try:
    # Attempt to open the file in read mode
    with open(filename, "r") as file:
        content = file.read()
        print("File content:")
        print(content)

except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
# Out:
# File content:
# Hello, this is a string written to the file.

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python?

# %%
lines = []
with open("/content/LINE.TEX.txt", "r") as file:
    for line in file:
        lines.append(line.strip())

print(lines)
# Out:
# ['Line 1: Hello', 'Line 2: Welcome to Python', 'Line 3: File reading example']

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %%
# Open the file in append mode
with open("/content/LINE.TEX.txt", "a") as file:
    file.write("This is a new line being appended.\n")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist.

# %%
# Sample dictionary
student = {
    "name": "Alice",
    "age": 20
}

try:
    # Attempt to access a key that may not exist
    grade = student["grade"]
    print("Grade:", grade)

except KeyError:
    print("Error: The key 'grade' does not exist in the dictionary.")
# Out:
# Error: The key 'grade' does not exist in the dictionary.

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
    # Example operations that can cause different exceptions
    num = int(input("Enter a number: "))       # May raise ValueError
    result = 10 / num                          # May raise ZeroDivisionError
    my_list = [1, 2, 3]
    print(my_list[5])                          # May raise IndexError

except ValueError:
    print("Error: Invalid input. Please enter a valid integer.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except IndexError:
    print("Error: List index out of range.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter a number: abc
# Error: Invalid input. Please enter a valid integer.

# %%
try:
    # Example operations that can cause different exceptions
    num = int(input("Enter a number: "))       # May raise ValueError
    result = 10 / num                          # May raise ZeroDivisionError
    my_list = [1, 2, 3]
    print(my_list[5])                          # May raise IndexError

except ValueError:
    print("Error: Invalid input. Please enter a valid integer.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except IndexError:
    print("Error: List index out of range.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter a number: 1
# Error: List index out of range.

# %%
try:
    # Example operations that can cause different exceptions
    num = int(input("Enter a number: "))       # May raise ValueError
    result = 10 / num                          # May raise ZeroDivisionError
    my_list = [1, 2, 3]
    print(my_list[5])                          # May raise IndexError

except ValueError:
    print("Error: Invalid input. Please enter a valid integer.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except IndexError:
    print("Error: List index out of range.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter a number: 0
# Error: Division by zero is not allowed.

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %%
import os

filename = "example.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        content = file.read()
        print("File content:")
        print(content)
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# File content:
# This is a new line being appended.
# This is a new line being appended.
# This is a new line being appended.
# Line 3: Python is great
# Line 4: File handling is easy

# %% [markdown]
# 14.  Write a program that uses the logging module to log both informational and error messages.

# %%
import logging

# Configure logging
logging.basicConfig(
    filename="app.log",             # Log file name
    level=logging.INFO,             # Minimum level to log
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Log an informational message
logging.info("Program started successfully.")

try:
    # Simulate a task that could fail
    x = 10
    y = 0
    result = x / y  # This will raise ZeroDivisionError

except ZeroDivisionError as e:
    # Log the error with details
    logging.error(f"Error occurred during division: {e}")

# Log another info message
logging.info("Program finished.")
# Out:
# ERROR:root:Error occurred during division: division by zero

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
filename = "/content/LINE.TEX.txt"

try:
    with open(filename, "r") as file:
        content = file.read()

        if not content:
            print(f"The file '{filename}' is empty.")
        else:
            print(f"Contents of '{filename}':\n")
            print(content)

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Contents of '/content/LINE.TEX.txt':
#
# Line 1: Hello
# Line 2: Welcome to Python
# Line 3: File reading exampleThis is a new line being appended.
# This is a new line being appended.
# Line 3: Python is great
# Line 4: File handling is easy

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
from memory_profiler import profile

@profile
def create_large_list():
    data = [i for i in range(1000000)]  # creates a list with 1 million items
    return data

if __name__ == "__main__":
    create_large_list()
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 847, in enable
#     sys.settrace(self.trace_memory_usage)
# ERROR: Could not find file /tmp/ipython-input-60-85454741.py
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 850, in disable
#     sys.settrace(self._original_trace_function)

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
# List of numbers
numbers = [10, 20, 30, 40, 50]

# Open the file in write mode
with open("/content/numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

print("Numbers have been written to 'numbers.txt'")
# Out:
# Numbers have been written to 'numbers.txt'

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

# Set up a rotating log handler
log_file = "app.log"
max_size_bytes = 1 * 1024 * 1024  # 1MB
backup_count = 3  # Keep last 3 rotated logs

# Configure the rotating handler
handler = RotatingFileHandler(
    log_file, maxBytes=max_size_bytes, backupCount=backup_count
)

# Set log format
formatter = logging.Formatter(
    "%(asctime)s - %(levelname)s - %(message)s"
)
handler.setFormatter(formatter)

# Configure root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.addHandler(handler)

# Log sample messages
for i in range(10000):
    logger.info(f"This is log message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:This is log message number 5000
# INFO:root:This is log message number 5001
# INFO:root:This is log message number 5002
# INFO:root:This is log message number 5003
# INFO:root:This is log message number 5004
# INFO:root:This is log message number 5005
# INFO:root:This is log message number 5006
# INFO:root:This is log message number 5007
# INFO:root:This is log message number 5008
# INFO:root:This is log message number 5009
# INFO:root:This is log message number 5010
# INFO:root:This is log message number 5011
# INFO:root:This is log message number 5012
# INFO:root:This is log message number 5013
# INFO:root:This is log message number 5014
# INFO:root:This is log message number 5015
# INFO:root:This is log message number 5016
# INFO:root:This is log message number 5017
# INFO:root:This is log message number 5018
# INFO:root:This is log message number 5019
# INFO:root:This is log message number 5020
# INFO:root:This is log message number 5021
# INFO:root:This is log message number 5022
# INFO:root:This is log message number 5023
# INFO:root:This is log message number 5024
# INFO:root:This is log message number 5025
# INFO:root:This is log message number 5026
# INFO:root:This is log message number 5027
# INFO:root:This is log message number 5028
# INFO:root:This is log message number 5029
# INFO:root:This is log message number 5030
# INFO:root:This is log message number 9769
# INFO:root:This is log message number 9770
# INFO:root:This is log message number 9771
# INFO:root:This is log message number 9772
# INFO:root:This is log message number 9773
# INFO:root:This is log message number 9774
# INFO:root:This is log message number 9775
# INFO:root:This is log message number 9776
# INFO:root:This is log message number 9777
# INFO:root:This is log message number 9778
# INFO:root:This is log message number 9779
# INFO:root:This is log message number 9780
# INFO:root:This is log message number 9781
# INFO:root:This is log message number 9782
# INFO:root:This is log message number 9783
# INFO:root:This is log message number 9784
# INFO:root:This is log message number 9785
# INFO:root:This is log message number 9786
# INFO:root:This is log message number 9787
# INFO:root:This is log message number 9788
# INFO:root:This is log message number 9789
# INFO:root:This is log message number 9790
# INFO:root:This is log message number 9791
# INFO:root:This is log message number 9792
# INFO:root:This is log message number 9793
# INFO:root:This is log message number 9794
# INFO:root:This is log message number 9795
# INFO:root:This is log message number 9796
# INFO:root:This is log message number 9797
# INFO:root:This is log message number 9798
# INFO:root:This is log message number 9799
# INFO:root:This is log message number 9800
# INFO:root:This is log message number 9801
# INFO:root:This is log message number 9802
# INFO:root:This is log message number 9803
# INFO:root:This is log message number 9804
# INFO:root:This is log message number 9805
# INFO:root:This is log message number 9806
# INFO:root:This is log message number 9807
# INFO:root:This is log message number 9808
# INFO:root:This is log message number 9809
# INFO:root:This is log message number 9810
# INFO:root:This is log message number 9811
# INFO:root:This is log message number 9812
# INFO:root:This is log message number 9813
# INFO:root:This is log message number 9814
# INFO:root:This is log message number 9815
# INFO:root:This is log message number 9816
# INFO:root:This is log message number 9817
# INFO:root:This is log message number 9818
# INFO:root:This is log message number 9819
# INFO:root:This is log message number 9820
# INFO:root:This is log message number 9821
# INFO:root:This is log message number 9822
# INFO:root:This is log message number 9823
# INFO:root:This is log message number 9824
# INFO:root:This is log message number 9825
# INFO:root:This is log message number 9826
# INFO:root:This is log message number 9827
# INFO:root:This is log message number 9828
# INFO:root:This is log message number 9829
# INFO:root:This is log message number 9830
# INFO:root:This is log message number 9831
# INFO:root:This is log message number 9832
# INFO:root:This is log message number 9833
# INFO:root:This is log message number 9834
# INFO:root:This is log message number 9835
# INFO:root:This is log message number 9836
# INFO:root:This is log message number 9837
# INFO:root:This is log message number 9838
# INFO:root:This is log message number 9839
# INFO:root:This is log message number 9840
# INFO:root:This is log message number 9841
# INFO:root:This is log message number 9842
# INFO:root:This is log message number 9843
# INFO:root:This is log message number 9844
# INFO:root:This is log message number 9845
# INFO:root:This is log message number 9846
# INFO:root:This is log message number 9847
# INFO:root:This is log message number 9848
# INFO:root:This is log message number 9849
# INFO:root:This is log message number 9850
# INFO:root:This is log message number 9851
# INFO:root:This is log message number 9852
# INFO:root:This is log message number 9853
# INFO:root:This is log message number 9854
# INFO:root:This is log message number 9855
# INFO:root:This is log message number 9856
# INFO:root:This is log message number 9857
# INFO:root:This is log message number 9858
# INFO:root:This is log message number 9859
# INFO:root:This is log message number 9860
# INFO:root:This is log message number 9861
# INFO:root:This is log message number 9862
# INFO:root:This is log message number 9863
# INFO:root:This is log message number 9864
# INFO:root:This is log message number 9865
# INFO:root:This is log message number 9866
# INFO:root:This is log message number 9867
# INFO:root:This is log message number 9868
# INFO:root:This is log message number 9869
# INFO:root:This is log message number 9870
# INFO:root:This is log message number 9871
# INFO:root:This is log message number 9872
# INFO:root:This is log message number 9873
# INFO:root:This is log message number 9874
# INFO:root:This is log message number 9875
# INFO:root:This is log message number 9876
# INFO:root:This is log message number 9877
# INFO:root:This is log message number 9878
# INFO:root:This is log message number 9879
# INFO:root:This is log message number 9880
# INFO:root:This is log message number 9881
# INFO:root:This is log message number 9882
# INFO:root:This is log message number 9883
# INFO:root:This is log message number 9884
# INFO:root:This is log message number 9885
# INFO:root:This is log message number 9886
# INFO:root:This is log message number 9887
# INFO:root:This is log message number 9888
# INFO:root:This is log message number 9889
# INFO:root:This is log message number 9890
# INFO:root:This is log message number 9891
# INFO:root:This is log message number 9892
# INFO:root:This is log message number 9893
# INFO:root:This is log message number 9894
# INFO:root:This is log message number 9895
# INFO:root:This is log message number 9896
# INFO:root:This is log message number 9897
# INFO:root:This is log message number 9898
# INFO:root:This is log message number 9899
# INFO:root:This is log message number 9900
# INFO:root:This is log message number 9901
# INFO:root:This is log message number 9902
# INFO:root:This is log message number 9903
# INFO:root:This is log message number 9904
# INFO:root:This is log message number 9905
# INFO:root:This is log message number 9906
# INFO:root:This is log message number 9907
# INFO:root:This is log message number 9908
# INFO:root:This is log message number 9909
# INFO:root:This is log message number 9910
# INFO:root:This is log message number 9911
# INFO:root:This is log message number 9912
# INFO:root:This is log message number 9913
# INFO:root:This is log message number 9914
# INFO:root:This is log message number 9915
# INFO:root:This is log message number 9916
# INFO:root:This is log message number 9917
# INFO:root:This is log message number 9918
# INFO:root:This is log message number 9919
# INFO:root:This is log message number 9920
# INFO:root:This is log message number 9921
# INFO:root:This is log message number 9922
# INFO:root:This is log message number 9923
# INFO:root:This is log message number 9924
# INFO:root:This is log message number 9925
# INFO:root:This is log message number 9926
# INFO:root:This is log message number 9927
# INFO:root:This is log message number 9928
# INFO:root:This is log message number 9929
# INFO:root:This is log message number 9930
# INFO:root:This is log message number 9931
# INFO:root:This is log message number 9932
# INFO:root:This is log message number 9933
# INFO:root:This is log message number 9934
# INFO:root:This is log message number 9935
# INFO:root:This is log message number 9936
# INFO:root:This is log message number 9937
# INFO:root:This is log message number 9938
# INFO:root:This is log message number 9939
# INFO:root:This is log message number 9940
# INFO:root:This is log message number 9941
# INFO:root:This is log message number 9942
# INFO:root:This is log message number 9943
# INFO:root:This is log message number 9944
# INFO:root:This is log message number 9945
# INFO:root:This is log message number 9946
# INFO:root:This is log message number 9947
# INFO:root:This is log message number 9948
# INFO:root:This is log message number 9949
# INFO:root:This is log message number 9950
# INFO:root:This is log message number 9951
# INFO:root:This is log message number 9952
# INFO:root:This is log message number 9953
# INFO:root:This is log message number 9954
# INFO:root:This is log message number 9955
# INFO:root:This is log message number 9956
# INFO:root:This is log message number 9957
# INFO:root:This is log message number 9958
# INFO:root:This is log message number 9959
# INFO:root:This is log message number 9960
# INFO:root:This is log message number 9961
# INFO:root:This is log message number 9962
# INFO:root:This is log message number 9963
# INFO:root:This is log message number 9964
# INFO:root:This is log message number 9965
# INFO:root:This is log message number 9966
# INFO:root:This is log message number 9967
# INFO:root:This is log message number 9968
# INFO:root:This is log message number 9969
# INFO:root:This is log message number 9970
# INFO:root:This is log message number 9971
# INFO:root:This is log message number 9972
# INFO:root:This is log message number 9973
# INFO:root:This is log message number 9974
# INFO:root:This is log message number 9975
# INFO:root:This is log message number 9976
# INFO:root:This is log message number 9977
# INFO:root:This is log message number 9978
# INFO:root:This is log message number 9979
# INFO:root:This is log message number 9980
# INFO:root:This is log message number 9981
# INFO:root:This is log message number 9982
# INFO:root:This is log message number 9983
# INFO:root:This is log message number 9984
# INFO:root:This is log message number 9985
# INFO:root:This is log message number 9986
# INFO:root:This is log message number 9987
# INFO:root:This is log message number 9988
# INFO:root:This is log message number 9989
# INFO:root:This is log message number 9990
# INFO:root:This is log message number 9991
# INFO:root:This is log message number 9992
# INFO:root:This is log message number 9993
# INFO:root:This is log message number 9994
# INFO:root:This is log message number 9995
# INFO:root:This is log message number 9996
# INFO:root:This is log message number 9997
# INFO:root:This is log message number 9998
# INFO:root:This is log message number 9999

# %%
import logging
from logging.handlers import RotatingFileHandler

# Set up a logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)  # Set the minimum log level

# Create a RotatingFileHandler
handler = RotatingFileHandler(
    "my_log.log",        # Log file name
    maxBytes=1 * 1024 * 1024,  # 1MB size limit
    backupCount=3             # Keep up to 3 backup files (my_log.log.1, .2, etc.)
)

# Create a formatter and set it for the handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example log messages
for i in range(10000):
    logger.debug(f"This is log message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:MyLogger:This is log message number 5000
# DEBUG:MyLogger:This is log message number 5001
# DEBUG:MyLogger:This is log message number 5002
# DEBUG:MyLogger:This is log message number 5003
# DEBUG:MyLogger:This is log message number 5004
# DEBUG:MyLogger:This is log message number 5005
# DEBUG:MyLogger:This is log message number 5006
# DEBUG:MyLogger:This is log message number 5007
# DEBUG:MyLogger:This is log message number 5008
# DEBUG:MyLogger:This is log message number 5009
# DEBUG:MyLogger:This is log message number 5010
# DEBUG:MyLogger:This is log message number 5011
# DEBUG:MyLogger:This is log message number 5012
# DEBUG:MyLogger:This is log message number 5013
# DEBUG:MyLogger:This is log message number 5014
# DEBUG:MyLogger:This is log message number 5015
# DEBUG:MyLogger:This is log message number 5016
# DEBUG:MyLogger:This is log message number 5017
# DEBUG:MyLogger:This is log message number 5018
# DEBUG:MyLogger:This is log message number 5019
# DEBUG:MyLogger:This is log message number 5020
# DEBUG:MyLogger:This is log message number 5021
# DEBUG:MyLogger:This is log message number 5022
# DEBUG:MyLogger:This is log message number 5023
# DEBUG:MyLogger:This is log message number 5024
# DEBUG:MyLogger:This is log message number 5025
# DEBUG:MyLogger:This is log message number 5026
# DEBUG:MyLogger:This is log message number 5027
# DEBUG:MyLogger:This is log message number 5028
# DEBUG:MyLogger:This is log message number 5029
# DEBUG:MyLogger:This is log message number 5030
# DEBUG:MyLogger:This is log message number 5031
# DEBUG:MyLogger:This is log message number 5032
# DEBUG:MyLogger:This is log message number 5033
# DEBUG:MyLogger:This is log message number 5034
# DEBUG:MyLogger:This is log message number 5035
# DEBUG:MyLogger:This is log message number 5036
# DEBUG:MyLogger:This is log message number 5037
# DEBUG:MyLogger:This is log message number 5038
# DEBUG:MyLogger:This is log message number 5039
# DEBUG:MyLogger:This is log message number 5040
# DEBUG:MyLogger:This is log message number 5041
# DEBUG:MyLogger:This is log message number 5042
# DEBUG:MyLogger:This is log message number 5043
# DEBUG:MyLogger:This is log message number 5044
# DEBUG:MyLogger:This is log message number 5045
# DEBUG:MyLogger:This is log message number 5046
# DEBUG:MyLogger:This is log message number 5047
# DEBUG:MyLogger:This is log message number 5048
# DEBUG:MyLogger:This is log message number 5049
# DEBUG:MyLogger:This is log message number 5050
# DEBUG:MyLogger:This is log message number 5051
# DEBUG:MyLogger:This is log message number 5052
# DEBUG:MyLogger:This is log message number 5053
# DEBUG:MyLogger:This is log message number 5054
# DEBUG:MyLogger:This is log message number 5055
# DEBUG:MyLogger:This is log message number 5056
# DEBUG:MyLogger:This is log message number 5057
# DEBUG:MyLogger:This is log message number 5058
# DEBUG:MyLogger:This is log message number 5059
# DEBUG:MyLogger:This is log message number 5060
# DEBUG:MyLogger:This is log message number 5061
# DEBUG:MyLogger:This is log message number 5062
# DEBUG:MyLogger:This is log message number 5063
# DEBUG:MyLogger:This is log message number 5064
# DEBUG:MyLogger:This is log message number 5065
# DEBUG:MyLogger:This is log message number 5066
# DEBUG:MyLogger:This is log message number 5067
# DEBUG:MyLogger:This is log message number 5068
# DEBUG:MyLogger:This is log message number 5069
# DEBUG:MyLogger:This is log message number 5070
# DEBUG:MyLogger:This is log message number 5071
# DEBUG:MyLogger:This is log message number 5072
# DEBUG:MyLogger:This is log message number 5073
# DEBUG:MyLogger:This is log message number 5074
# DEBUG:MyLogger:This is log message number 5075
# DEBUG:MyLogger:This is log message number 5076
# DEBUG:MyLogger:This is log message number 5077
# DEBUG:MyLogger:This is log message number 5078
# DEBUG:MyLogger:This is log message number 5079
# DEBUG:MyLogger:This is log message number 5080
# DEBUG:MyLogger:This is log message number 5081
# DEBUG:MyLogger:This is log message number 5082
# DEBUG:MyLogger:This is log message number 5083
# DEBUG:MyLogger:This is log message number 5084
# DEBUG:MyLogger:This is log message number 5085
# DEBUG:MyLogger:This is log message number 5086
# DEBUG:MyLogger:This is log message number 5087
# DEBUG:MyLogger:This is log message number 5088
# DEBUG:MyLogger:This is log message number 5089
# DEBUG:MyLogger:This is log message number 5090
# DEBUG:MyLogger:This is log message number 5091
# DEBUG:MyLogger:This is log message number 5092
# DEBUG:MyLogger:This is log message number 5093
# DEBUG:MyLogger:This is log message number 5094
# DEBUG:MyLogger:This is log message number 5095
# DEBUG:MyLogger:This is log message number 5096
# DEBUG:MyLogger:This is log message number 5097
# DEBUG:MyLogger:This is log message number 5098
# DEBUG:MyLogger:This is log message number 5099
# DEBUG:MyLogger:This is log message number 5100
# DEBUG:MyLogger:This is log message number 5101
# DEBUG:MyLogger:This is log message number 5102
# DEBUG:MyLogger:This is log message number 5103
# DEBUG:MyLogger:This is log message number 5104
# DEBUG:MyLogger:This is log message number 5105
# DEBUG:MyLogger:This is log message number 5106
# DEBUG:MyLogger:This is log message number 5107
# DEBUG:MyLogger:This is log message number 5108
# DEBUG:MyLogger:This is log message number 5109
# DEBUG:MyLogger:This is log message number 5110
# DEBUG:MyLogger:This is log message number 5111
# DEBUG:MyLogger:This is log message number 5112
# DEBUG:MyLogger:This is log message number 5113
# DEBUG:MyLogger:This is log message number 5114
# DEBUG:MyLogger:This is log message number 5115
# DEBUG:MyLogger:This is log message number 5116
# DEBUG:MyLogger:This is log message number 5117
# DEBUG:MyLogger:This is log message number 5118
# DEBUG:MyLogger:This is log message number 5119
# DEBUG:MyLogger:This is log message number 5120
# DEBUG:MyLogger:This is log message number 5121
# DEBUG:MyLogger:This is log message number 5122
# DEBUG:MyLogger:This is log message number 5123
# DEBUG:MyLogger:This is log message number 5124
# DEBUG:MyLogger:This is log message number 5125
# DEBUG:MyLogger:This is log message number 5126
# DEBUG:MyLogger:This is log message number 5127
# DEBUG:MyLogger:This is log message number 5128
# DEBUG:MyLogger:This is log message number 5129
# DEBUG:MyLogger:This is log message number 5130
# DEBUG:MyLogger:This is log message number 5131
# DEBUG:MyLogger:This is log message number 5132
# DEBUG:MyLogger:This is log message number 5133
# DEBUG:MyLogger:This is log message number 5134
# DEBUG:MyLogger:This is log message number 5135
# DEBUG:MyLogger:This is log message number 5136
# DEBUG:MyLogger:This is log message number 5137
# DEBUG:MyLogger:This is log message number 5138
# DEBUG:MyLogger:This is log message number 5139
# DEBUG:MyLogger:This is log message number 5140
# DEBUG:MyLogger:This is log message number 5141
# DEBUG:MyLogger:This is log message number 5142
# DEBUG:MyLogger:This is log message number 5143
# DEBUG:MyLogger:This is log message number 5144
# DEBUG:MyLogger:This is log message number 5145
# DEBUG:MyLogger:This is log message number 5146
# DEBUG:MyLogger:This is log message number 5147
# DEBUG:MyLogger:This is log message number 5148
# DEBUG:MyLogger:This is log message number 5149
# DEBUG:MyLogger:This is log message number 5150
# DEBUG:MyLogger:This is log message number 5151
# DEBUG:MyLogger:This is log message number 5152
# DEBUG:MyLogger:This is log message number 5153
# DEBUG:MyLogger:This is log message number 5154
# DEBUG:MyLogger:This is log message number 5155
# DEBUG:MyLogger:This is log message number 5156
# DEBUG:MyLogger:This is log message number 5157
# DEBUG:MyLogger:This is log message number 5158
# DEBUG:MyLogger:This is log message number 5159
# DEBUG:MyLogger:This is log message number 5160
# DEBUG:MyLogger:This is log message number 5161
# DEBUG:MyLogger:This is log message number 5162
# DEBUG:MyLogger:This is log message number 5163
# DEBUG:MyLogger:This is log message number 5164
# DEBUG:MyLogger:This is log message number 5165
# DEBUG:MyLogger:This is log message number 5166
# DEBUG:MyLogger:This is log message number 5167
# DEBUG:MyLogger:This is log message number 5168
# DEBUG:MyLogger:This is log message number 5169
# DEBUG:MyLogger:This is log message number 5170
# DEBUG:MyLogger:This is log message number 5171
# DEBUG:MyLogger:This is log message number 5172
# DEBUG:MyLogger:This is log message number 5173
# DEBUG:MyLogger:This is log message number 5174
# DEBUG:MyLogger:This is log message number 5175
# DEBUG:MyLogger:This is log message number 5176
# DEBUG:MyLogger:This is log message number 5177
# DEBUG:MyLogger:This is log message number 5178
# DEBUG:MyLogger:This is log message number 5179
# DEBUG:MyLogger:This is log message number 5180
# DEBUG:MyLogger:This is log message number 5181
# DEBUG:MyLogger:This is log message number 5182
# DEBUG:MyLogger:This is log message number 5183
# DEBUG:MyLogger:This is log message number 5184
# DEBUG:MyLogger:This is log message number 5185
# DEBUG:MyLogger:This is log message number 5186
# DEBUG:MyLogger:This is log message number 5187
# DEBUG:MyLogger:This is log message number 5188
# DEBUG:MyLogger:This is log message number 5189
# DEBUG:MyLogger:This is log message number 5190
# DEBUG:MyLogger:This is log message number 5191
# DEBUG:MyLogger:This is log message number 5192
# DEBUG:MyLogger:This is log message number 5193
# DEBUG:MyLogger:This is log message number 5194
# DEBUG:MyLogger:This is log message number 5195
# DEBUG:MyLogger:This is log message number 5196
# DEBUG:MyLogger:This is log message number 5197
# DEBUG:MyLogger:This is log message number 5198
# DEBUG:MyLogger:This is log message number 5199
# DEBUG:MyLogger:This is log message number 5200
# DEBUG:MyLogger:This is log message number 5201
# DEBUG:MyLogger:This is log message number 5202
# DEBUG:MyLogger:This is log message number 5203
# DEBUG:MyLogger:This is log message number 5204
# DEBUG:MyLogger:This is log message number 5205
# DEBUG:MyLogger:This is log message number 5206
# DEBUG:MyLogger:This is log message number 5207
# DEBUG:MyLogger:This is log message number 5208
# DEBUG:MyLogger:This is log message number 5209
# DEBUG:MyLogger:This is log message number 5210
# DEBUG:MyLogger:This is log message number 5211
# DEBUG:MyLogger:This is log message number 5212
# DEBUG:MyLogger:This is log message number 5213
# DEBUG:MyLogger:This is log message number 5214
# DEBUG:MyLogger:This is log message number 5215
# DEBUG:MyLogger:This is log message number 5216
# DEBUG:MyLogger:This is log message number 5217
# DEBUG:MyLogger:This is log message number 5218
# DEBUG:MyLogger:This is log message number 5219
# DEBUG:MyLogger:This is log message number 5220
# DEBUG:MyLogger:This is log message number 5221
# DEBUG:MyLogger:This is log message number 5222
# DEBUG:MyLogger:This is log message number 5223
# DEBUG:MyLogger:This is log message number 5224
# DEBUG:MyLogger:This is log message number 5225
# DEBUG:MyLogger:This is log message number 5226
# DEBUG:MyLogger:This is log message number 5227
# DEBUG:MyLogger:This is log message number 5228
# DEBUG:MyLogger:This is log message number 5229
# DEBUG:MyLogger:This is log message number 5230
# DEBUG:MyLogger:This is log message number 5231
# DEBUG:MyLogger:This is log message number 5232
# DEBUG:MyLogger:This is log message number 5233
# DEBUG:MyLogger:This is log message number 5234
# DEBUG:MyLogger:This is log message number 5235
# DEBUG:MyLogger:This is log message number 5236
# DEBUG:MyLogger:This is log message number 5237
# DEBUG:MyLogger:This is log message number 5238
# DEBUG:MyLogger:This is log message number 5239
# DEBUG:MyLogger:This is log message number 5240
# DEBUG:MyLogger:This is log message number 5241
# DEBUG:MyLogger:This is log message number 5242
# DEBUG:MyLogger:This is log message number 5243
# DEBUG:MyLogger:This is log message number 5244
# DEBUG:MyLogger:This is log message number 5245
# DEBUG:MyLogger:This is log message number 5246
# DEBUG:MyLogger:This is log message number 5247
# DEBUG:MyLogger:This is log message number 5248
# DEBUG:MyLogger:This is log message number 5249
# DEBUG:MyLogger:This is log message number 5250
# DEBUG:MyLogger:This is log message number 5251
# DEBUG:MyLogger:This is log message number 5252
# DEBUG:MyLogger:This is log message number 5253
# DEBUG:MyLogger:This is log message number 5254
# DEBUG:MyLogger:This is log message number 5255
# DEBUG:MyLogger:This is log message number 5256
# DEBUG:MyLogger:This is log message number 5257
# DEBUG:MyLogger:This is log message number 5258
# DEBUG:MyLogger:This is log message number 5259
# DEBUG:MyLogger:This is log message number 5260
# DEBUG:MyLogger:This is log message number 5261
# DEBUG:MyLogger:This is log message number 5262
# DEBUG:MyLogger:This is log message number 5263
# DEBUG:MyLogger:This is log message number 5264
# DEBUG:MyLogger:This is log message number 5265
# DEBUG:MyLogger:This is log message number 5266
# DEBUG:MyLogger:This is log message number 5267
# DEBUG:MyLogger:This is log message number 5268
# DEBUG:MyLogger:This is log message number 5269
# DEBUG:MyLogger:This is log message number 5270
# DEBUG:MyLogger:This is log message number 5271
# DEBUG:MyLogger:This is log message number 5272
# DEBUG:MyLogger:This is log message number 5273
# DEBUG:MyLogger:This is log message number 5274
# DEBUG:MyLogger:This is log message number 5275
# DEBUG:MyLogger:This is log message number 5276
# DEBUG:MyLogger:This is log message number 5277
# DEBUG:MyLogger:This is log message number 5278
# DEBUG:MyLogger:This is log message number 5279
# DEBUG:MyLogger:This is log message number 5280
# DEBUG:MyLogger:This is log message number 5281
# DEBUG:MyLogger:This is log message number 5282
# DEBUG:MyLogger:This is log message number 5283
# DEBUG:MyLogger:This is log message number 5284
# DEBUG:MyLogger:This is log message number 5285
# DEBUG:MyLogger:This is log message number 5286
# DEBUG:MyLogger:This is log message number 5287
# DEBUG:MyLogger:This is log message number 5288
# DEBUG:MyLogger:This is log message number 5289
# DEBUG:MyLogger:This is log message number 5290
# DEBUG:MyLogger:This is log message number 5291
# DEBUG:MyLogger:This is log message number 5292
# DEBUG:MyLogger:This is log message number 5293
# DEBUG:MyLogger:This is log message number 5294
# DEBUG:MyLogger:This is log message number 5295
# DEBUG:MyLogger:This is log message number 5296
# DEBUG:MyLogger:This is log message number 5297
# DEBUG:MyLogger:This is log message number 5298
# DEBUG:MyLogger:This is log message number 5299
# DEBUG:MyLogger:This is log message number 5300
# DEBUG:MyLogger:This is log message number 5301
# DEBUG:MyLogger:This is log message number 5302
# DEBUG:MyLogger:This is log message number 5303
# DEBUG:MyLogger:This is log message number 5304
# DEBUG:MyLogger:This is log message number 5305
# DEBUG:MyLogger:This is log message number 5306
# DEBUG:MyLogger:This is log message number 5307
# DEBUG:MyLogger:This is log message number 5308
# DEBUG:MyLogger:This is log message number 5309
# DEBUG:MyLogger:This is log message number 5310
# DEBUG:MyLogger:This is log message number 5311
# DEBUG:MyLogger:This is log message number 5312
# DEBUG:MyLogger:This is log message number 5313
# DEBUG:MyLogger:This is log message number 5314
# DEBUG:MyLogger:This is log message number 5315
# DEBUG:MyLogger:This is log message number 5316
# DEBUG:MyLogger:This is log message number 5317
# DEBUG:MyLogger:This is log message number 5318
# DEBUG:MyLogger:This is log message number 5319
# DEBUG:MyLogger:This is log message number 5320
# DEBUG:MyLogger:This is log message number 5321
# DEBUG:MyLogger:This is log message number 5322
# DEBUG:MyLogger:This is log message number 5323
# DEBUG:MyLogger:This is log message number 5324
# DEBUG:MyLogger:This is log message number 5325
# DEBUG:MyLogger:This is log message number 5326
# DEBUG:MyLogger:This is log message number 5327
# DEBUG:MyLogger:This is log message number 5328
# DEBUG:MyLogger:This is log message number 5329
# DEBUG:MyLogger:This is log message number 5330
# DEBUG:MyLogger:This is log message number 5331
# DEBUG:MyLogger:This is log message number 5332
# DEBUG:MyLogger:This is log message number 5333
# DEBUG:MyLogger:This is log message number 5334
# DEBUG:MyLogger:This is log message number 5335
# DEBUG:MyLogger:This is log message number 5336
# DEBUG:MyLogger:This is log message number 5337
# DEBUG:MyLogger:This is log message number 5338
# DEBUG:MyLogger:This is log message number 5339
# DEBUG:MyLogger:This is log message number 5340
# DEBUG:MyLogger:This is log message number 5341
# DEBUG:MyLogger:This is log message number 5342
# DEBUG:MyLogger:This is log message number 5343
# DEBUG:MyLogger:This is log message number 5344
# DEBUG:MyLogger:This is log message number 5345
# DEBUG:MyLogger:This is log message number 5346
# DEBUG:MyLogger:This is log message number 5347
# DEBUG:MyLogger:This is log message number 5348
# DEBUG:MyLogger:This is log message number 5349
# DEBUG:MyLogger:This is log message number 5350
# DEBUG:MyLogger:This is log message number 5351
# DEBUG:MyLogger:This is log message number 5352
# DEBUG:MyLogger:This is log message number 5353
# DEBUG:MyLogger:This is log message number 5354
# DEBUG:MyLogger:This is log message number 5355
# DEBUG:MyLogger:This is log message number 5356
# DEBUG:MyLogger:This is log message number 5357
# DEBUG:MyLogger:This is log message number 5358
# DEBUG:MyLogger:This is log message number 5359
# DEBUG:MyLogger:This is log message number 5360
# DEBUG:MyLogger:This is log message number 5361
# DEBUG:MyLogger:This is log message number 5362
# DEBUG:MyLogger:This is log message number 5363
# DEBUG:MyLogger:This is log message number 5364
# DEBUG:MyLogger:This is log message number 5365
# DEBUG:MyLogger:This is log message number 5366
# DEBUG:MyLogger:This is log message number 5367
# DEBUG:MyLogger:This is log message number 5368
# DEBUG:MyLogger:This is log message number 5369
# DEBUG:MyLogger:This is log message number 5370
# DEBUG:MyLogger:This is log message number 5371
# DEBUG:MyLogger:This is log message number 5372
# DEBUG:MyLogger:This is log message number 5373
# DEBUG:MyLogger:This is log message number 5374
# DEBUG:MyLogger:This is log message number 5375
# DEBUG:MyLogger:This is log message number 5376
# DEBUG:MyLogger:This is log message number 5377
# DEBUG:MyLogger:This is log message number 5378
# DEBUG:MyLogger:This is log message number 5379
# DEBUG:MyLogger:This is log message number 5380
# DEBUG:MyLogger:This is log message number 5381
# DEBUG:MyLogger:This is log message number 5382
# DEBUG:MyLogger:This is log message number 5383
# DEBUG:MyLogger:This is log message number 5384
# DEBUG:MyLogger:This is log message number 5385
# DEBUG:MyLogger:This is log message number 5386
# DEBUG:MyLogger:This is log message number 5387
# DEBUG:MyLogger:This is log message number 5388
# DEBUG:MyLogger:This is log message number 5389
# DEBUG:MyLogger:This is log message number 5390
# DEBUG:MyLogger:This is log message number 5391
# DEBUG:MyLogger:This is log message number 5392
# DEBUG:MyLogger:This is log message number 5393
# DEBUG:MyLogger:This is log message number 5394
# DEBUG:MyLogger:This is log message number 5395
# DEBUG:MyLogger:This is log message number 5396
# DEBUG:MyLogger:This is log message number 5397
# DEBUG:MyLogger:This is log message number 5398
# DEBUG:MyLogger:This is log message number 5399
# DEBUG:MyLogger:This is log message number 5400
# DEBUG:MyLogger:This is log message number 5401
# DEBUG:MyLogger:This is log message number 5402
# DEBUG:MyLogger:This is log message number 5403
# DEBUG:MyLogger:This is log message number 5404
# DEBUG:MyLogger:This is log message number 5405
# DEBUG:MyLogger:This is log message number 5406
# DEBUG:MyLogger:This is log message number 5407
# DEBUG:MyLogger:This is log message number 5408
# DEBUG:MyLogger:This is log message number 5409
# DEBUG:MyLogger:This is log message number 5410
# DEBUG:MyLogger:This is log message number 5411
# DEBUG:MyLogger:This is log message number 5412
# DEBUG:MyLogger:This is log message number 5413
# DEBUG:MyLogger:This is log message number 5414
# DEBUG:MyLogger:This is log message number 5415
# DEBUG:MyLogger:This is log message number 5416
# DEBUG:MyLogger:This is log message number 5417
# DEBUG:MyLogger:This is log message number 5418
# DEBUG:MyLogger:This is log message number 5419
# DEBUG:MyLogger:This is log message number 5420
# DEBUG:MyLogger:This is log message number 5421
# DEBUG:MyLogger:This is log message number 5422
# DEBUG:MyLogger:This is log message number 5423
# DEBUG:MyLogger:This is log message number 5424
# DEBUG:MyLogger:This is log message number 5425
# DEBUG:MyLogger:This is log message number 5426
# DEBUG:MyLogger:This is log message number 5427
# DEBUG:MyLogger:This is log message number 5428
# DEBUG:MyLogger:This is log message number 5429
# DEBUG:MyLogger:This is log message number 5430
# DEBUG:MyLogger:This is log message number 5431
# DEBUG:MyLogger:This is log message number 5432
# DEBUG:MyLogger:This is log message number 5433
# DEBUG:MyLogger:This is log message number 5434
# DEBUG:MyLogger:This is log message number 5435
# DEBUG:MyLogger:This is log message number 5436
# DEBUG:MyLogger:This is log message number 5437
# DEBUG:MyLogger:This is log message number 5438
# DEBUG:MyLogger:This is log message number 5439
# DEBUG:MyLogger:This is log message number 5440
# DEBUG:MyLogger:This is log message number 5441
# DEBUG:MyLogger:This is log message number 5442
# DEBUG:MyLogger:This is log message number 5443
# DEBUG:MyLogger:This is log message number 5444
# DEBUG:MyLogger:This is log message number 5445
# DEBUG:MyLogger:This is log message number 5446
# DEBUG:MyLogger:This is log message number 5447
# DEBUG:MyLogger:This is log message number 5448
# DEBUG:MyLogger:This is log message number 5449
# DEBUG:MyLogger:This is log message number 5450
# DEBUG:MyLogger:This is log message number 5451
# DEBUG:MyLogger:This is log message number 5452
# DEBUG:MyLogger:This is log message number 5453
# DEBUG:MyLogger:This is log message number 5454
# DEBUG:MyLogger:This is log message number 5455
# DEBUG:MyLogger:This is log message number 5456
# DEBUG:MyLogger:This is log message number 5457
# DEBUG:MyLogger:This is log message number 5458
# DEBUG:MyLogger:This is log message number 5459
# DEBUG:MyLogger:This is log message number 5460
# DEBUG:MyLogger:This is log message number 5461
# DEBUG:MyLogger:This is log message number 5462
# DEBUG:MyLogger:This is log message number 5463
# DEBUG:MyLogger:This is log message number 5464
# DEBUG:MyLogger:This is log message number 5465
# DEBUG:MyLogger:This is log message number 5466
# DEBUG:MyLogger:This is log message number 5467
# DEBUG:MyLogger:This is log message number 5468
# DEBUG:MyLogger:This is log message number 5469
# DEBUG:MyLogger:This is log message number 5470
# DEBUG:MyLogger:This is log message number 5471
# DEBUG:MyLogger:This is log message number 5472
# DEBUG:MyLogger:This is log message number 5473
# DEBUG:MyLogger:This is log message number 5474
# DEBUG:MyLogger:This is log message number 5475
# DEBUG:MyLogger:This is log message number 5476
# DEBUG:MyLogger:This is log message number 5477
# DEBUG:MyLogger:This is log message number 5478
# DEBUG:MyLogger:This is log message number 5479
# DEBUG:MyLogger:This is log message number 5480
# DEBUG:MyLogger:This is log message number 5481
# DEBUG:MyLogger:This is log message number 5482
# DEBUG:MyLogger:This is log message number 5483
# DEBUG:MyLogger:This is log message number 5484
# DEBUG:MyLogger:This is log message number 5485
# DEBUG:MyLogger:This is log message number 5486
# DEBUG:MyLogger:This is log message number 5487
# DEBUG:MyLogger:This is log message number 5488
# DEBUG:MyLogger:This is log message number 5489
# DEBUG:MyLogger:This is log message number 5490
# DEBUG:MyLogger:This is log message number 5491
# DEBUG:MyLogger:This is log message number 5492
# DEBUG:MyLogger:This is log message number 5493
# DEBUG:MyLogger:This is log message number 5494
# DEBUG:MyLogger:This is log message number 5495
# DEBUG:MyLogger:This is log message number 5496
# DEBUG:MyLogger:This is log message number 5497
# DEBUG:MyLogger:This is log message number 5498
# DEBUG:MyLogger:This is log message number 5499
# DEBUG:MyLogger:This is log message number 5500
# DEBUG:MyLogger:This is log message number 5501
# DEBUG:MyLogger:This is log message number 5502
# DEBUG:MyLogger:This is log message number 5503
# DEBUG:MyLogger:This is log message number 5504
# DEBUG:MyLogger:This is log message number 5505
# DEBUG:MyLogger:This is log message number 5506
# DEBUG:MyLogger:This is log message number 5507
# DEBUG:MyLogger:This is log message number 5508
# DEBUG:MyLogger:This is log message number 5509
# DEBUG:MyLogger:This is log message number 5510
# DEBUG:MyLogger:This is log message number 5511
# DEBUG:MyLogger:This is log message number 5512
# DEBUG:MyLogger:This is log message number 5513
# DEBUG:MyLogger:This is log message number 5514
# DEBUG:MyLogger:This is log message number 5515
# DEBUG:MyLogger:This is log message number 5516
# DEBUG:MyLogger:This is log message number 5517
# DEBUG:MyLogger:This is log message number 5518
# DEBUG:MyLogger:This is log message number 5519
# DEBUG:MyLogger:This is log message number 5520
# DEBUG:MyLogger:This is log message number 5521
# DEBUG:MyLogger:This is log message number 5522
# DEBUG:MyLogger:This is log message number 5523
# DEBUG:MyLogger:This is log message number 5524
# DEBUG:MyLogger:This is log message number 5525
# DEBUG:MyLogger:This is log message number 5526
# DEBUG:MyLogger:This is log message number 5527
# DEBUG:MyLogger:This is log message number 5528
# DEBUG:MyLogger:This is log message number 5529
# DEBUG:MyLogger:This is log message number 5530
# DEBUG:MyLogger:This is log message number 5531
# DEBUG:MyLogger:This is log message number 5532
# DEBUG:MyLogger:This is log message number 5533
# DEBUG:MyLogger:This is log message number 5534
# DEBUG:MyLogger:This is log message number 5535
# DEBUG:MyLogger:This is log message number 5536
# DEBUG:MyLogger:This is log message number 5537
# DEBUG:MyLogger:This is log message number 5538
# DEBUG:MyLogger:This is log message number 5539
# DEBUG:MyLogger:This is log message number 5540
# DEBUG:MyLogger:This is log message number 5541
# DEBUG:MyLogger:This is log message number 5542
# DEBUG:MyLogger:This is log message number 5543
# DEBUG:MyLogger:This is log message number 5544
# DEBUG:MyLogger:This is log message number 5545
# DEBUG:MyLogger:This is log message number 5546
# DEBUG:MyLogger:This is log message number 5547
# DEBUG:MyLogger:This is log message number 5548
# DEBUG:MyLogger:This is log message number 5549
# DEBUG:MyLogger:This is log message number 5550
# DEBUG:MyLogger:This is log message number 5551
# DEBUG:MyLogger:This is log message number 5552
# DEBUG:MyLogger:This is log message number 5553
# DEBUG:MyLogger:This is log message number 5554
# DEBUG:MyLogger:This is log message number 5555
# DEBUG:MyLogger:This is log message number 5556
# DEBUG:MyLogger:This is log message number 5557
# DEBUG:MyLogger:This is log message number 5558
# DEBUG:MyLogger:This is log message number 5559
# DEBUG:MyLogger:This is log message number 5560
# DEBUG:MyLogger:This is log message number 5561
# DEBUG:MyLogger:This is log message number 5562
# DEBUG:MyLogger:This is log message number 5563
# DEBUG:MyLogger:This is log message number 5564
# DEBUG:MyLogger:This is log message number 5565
# DEBUG:MyLogger:This is log message number 5566
# DEBUG:MyLogger:This is log message number 5567
# DEBUG:MyLogger:This is log message number 5568
# DEBUG:MyLogger:This is log message number 5569
# DEBUG:MyLogger:This is log message number 5570
# DEBUG:MyLogger:This is log message number 5571
# DEBUG:MyLogger:This is log message number 5572
# DEBUG:MyLogger:This is log message number 5573
# DEBUG:MyLogger:This is log message number 5574
# DEBUG:MyLogger:This is log message number 5575
# DEBUG:MyLogger:This is log message number 5576
# DEBUG:MyLogger:This is log message number 5577
# DEBUG:MyLogger:This is log message number 5578
# DEBUG:MyLogger:This is log message number 5579
# DEBUG:MyLogger:This is log message number 5580
# DEBUG:MyLogger:This is log message number 5581
# DEBUG:MyLogger:This is log message number 5582
# DEBUG:MyLogger:This is log message number 5583
# DEBUG:MyLogger:This is log message number 5584
# DEBUG:MyLogger:This is log message number 5585
# DEBUG:MyLogger:This is log message number 5586
# DEBUG:MyLogger:This is log message number 5587
# DEBUG:MyLogger:This is log message number 5588
# DEBUG:MyLogger:This is log message number 5589
# DEBUG:MyLogger:This is log message number 5590
# DEBUG:MyLogger:This is log message number 5591
# DEBUG:MyLogger:This is log message number 5592
# DEBUG:MyLogger:This is log message number 5593
# DEBUG:MyLogger:This is log message number 5594
# DEBUG:MyLogger:This is log message number 5595
# DEBUG:MyLogger:This is log message number 5596
# DEBUG:MyLogger:This is log message number 5597
# DEBUG:MyLogger:This is log message number 5598
# DEBUG:MyLogger:This is log message number 5599
# DEBUG:MyLogger:This is log message number 5600
# DEBUG:MyLogger:This is log message number 5601
# DEBUG:MyLogger:This is log message number 5602
# DEBUG:MyLogger:This is log message number 5603
# DEBUG:MyLogger:This is log message number 5604
# DEBUG:MyLogger:This is log message number 5605
# DEBUG:MyLogger:This is log message number 5606
# DEBUG:MyLogger:This is log message number 5607
# DEBUG:MyLogger:This is log message number 5608
# DEBUG:MyLogger:This is log message number 5609
# DEBUG:MyLogger:This is log message number 5610
# DEBUG:MyLogger:This is log message number 5611
# DEBUG:MyLogger:This is log message number 5612
# DEBUG:MyLogger:This is log message number 5613
# DEBUG:MyLogger:This is log message number 5614
# DEBUG:MyLogger:This is log message number 5615
# DEBUG:MyLogger:This is log message number 5616
# DEBUG:MyLogger:This is log message number 5617
# DEBUG:MyLogger:This is log message number 5618
# DEBUG:MyLogger:This is log message number 5619
# DEBUG:MyLogger:This is log message number 5620
# DEBUG:MyLogger:This is log message number 5621
# DEBUG:MyLogger:This is log message number 5622
# DEBUG:MyLogger:This is log message number 5623
# DEBUG:MyLogger:This is log message number 5624
# DEBUG:MyLogger:This is log message number 5625
# DEBUG:MyLogger:This is log message number 5626
# DEBUG:MyLogger:This is log message number 5627
# DEBUG:MyLogger:This is log message number 5628
# DEBUG:MyLogger:This is log message number 5629
# DEBUG:MyLogger:This is log message number 5630
# DEBUG:MyLogger:This is log message number 5631
# DEBUG:MyLogger:This is log message number 5632
# DEBUG:MyLogger:This is log message number 5633
# DEBUG:MyLogger:This is log message number 5634
# DEBUG:MyLogger:This is log message number 5635
# DEBUG:MyLogger:This is log message number 5636
# DEBUG:MyLogger:This is log message number 5637
# DEBUG:MyLogger:This is log message number 5638
# DEBUG:MyLogger:This is log message number 5639
# DEBUG:MyLogger:This is log message number 5640
# DEBUG:MyLogger:This is log message number 5641
# DEBUG:MyLogger:This is log message number 5642
# DEBUG:MyLogger:This is log message number 5643
# DEBUG:MyLogger:This is log message number 5644
# DEBUG:MyLogger:This is log message number 5645
# DEBUG:MyLogger:This is log message number 5646
# DEBUG:MyLogger:This is log message number 5647
# DEBUG:MyLogger:This is log message number 5648
# DEBUG:MyLogger:This is log message number 5649
# DEBUG:MyLogger:This is log message number 5650
# DEBUG:MyLogger:This is log message number 5651
# DEBUG:MyLogger:This is log message number 5652
# DEBUG:MyLogger:This is log message number 5653
# DEBUG:MyLogger:This is log message number 5654
# DEBUG:MyLogger:This is log message number 5655
# DEBUG:MyLogger:This is log message number 5656
# DEBUG:MyLogger:This is log message number 5657
# DEBUG:MyLogger:This is log message number 5658
# DEBUG:MyLogger:This is log message number 5659
# DEBUG:MyLogger:This is log message number 5660
# DEBUG:MyLogger:This is log message number 5661
# DEBUG:MyLogger:This is log message number 5662
# DEBUG:MyLogger:This is log message number 5663
# DEBUG:MyLogger:This is log message number 5664
# DEBUG:MyLogger:This is log message number 5665
# DEBUG:MyLogger:This is log message number 5666
# DEBUG:MyLogger:This is log message number 5667
# DEBUG:MyLogger:This is log message number 5668
# DEBUG:MyLogger:This is log message number 5669
# DEBUG:MyLogger:This is log message number 5670
# DEBUG:MyLogger:This is log message number 5671
# DEBUG:MyLogger:This is log message number 5672
# DEBUG:MyLogger:This is log message number 5673
# DEBUG:MyLogger:This is log message number 5674
# DEBUG:MyLogger:This is log message number 5675
# DEBUG:MyLogger:This is log message number 5676
# DEBUG:MyLogger:This is log message number 5677
# DEBUG:MyLogger:This is log message number 5678
# DEBUG:MyLogger:This is log message number 5679
# DEBUG:MyLogger:This is log message number 5680
# DEBUG:MyLogger:This is log message number 5681
# DEBUG:MyLogger:This is log message number 5682
# DEBUG:MyLogger:This is log message number 5683
# DEBUG:MyLogger:This is log message number 5684
# DEBUG:MyLogger:This is log message number 5685
# DEBUG:MyLogger:This is log message number 5686
# DEBUG:MyLogger:This is log message number 5687
# DEBUG:MyLogger:This is log message number 5688
# DEBUG:MyLogger:This is log message number 5689
# DEBUG:MyLogger:This is log message number 5690
# DEBUG:MyLogger:This is log message number 5691
# DEBUG:MyLogger:This is log message number 5692
# DEBUG:MyLogger:This is log message number 5693
# DEBUG:MyLogger:This is log message number 5694
# DEBUG:MyLogger:This is log message number 5695
# DEBUG:MyLogger:This is log message number 5696
# DEBUG:MyLogger:This is log message number 5697
# DEBUG:MyLogger:This is log message number 5698
# DEBUG:MyLogger:This is log message number 5699
# DEBUG:MyLogger:This is log message number 5700
# DEBUG:MyLogger:This is log message number 5701
# DEBUG:MyLogger:This is log message number 5702
# DEBUG:MyLogger:This is log message number 5703
# DEBUG:MyLogger:This is log message number 5704
# DEBUG:MyLogger:This is log message number 5705
# DEBUG:MyLogger:This is log message number 5706
# DEBUG:MyLogger:This is log message number 5707
# DEBUG:MyLogger:This is log message number 5708
# DEBUG:MyLogger:This is log message number 5709
# DEBUG:MyLogger:This is log message number 5710
# DEBUG:MyLogger:This is log message number 5711
# DEBUG:MyLogger:This is log message number 5712
# DEBUG:MyLogger:This is log message number 5713
# DEBUG:MyLogger:This is log message number 5714
# DEBUG:MyLogger:This is log message number 5715
# DEBUG:MyLogger:This is log message number 5716
# DEBUG:MyLogger:This is log message number 5717
# DEBUG:MyLogger:This is log message number 5718
# DEBUG:MyLogger:This is log message number 5719
# DEBUG:MyLogger:This is log message number 5720
# DEBUG:MyLogger:This is log message number 5721
# DEBUG:MyLogger:This is log message number 5722
# DEBUG:MyLogger:This is log message number 5723
# DEBUG:MyLogger:This is log message number 5724
# DEBUG:MyLogger:This is log message number 5725
# DEBUG:MyLogger:This is log message number 5726
# DEBUG:MyLogger:This is log message number 5727
# DEBUG:MyLogger:This is log message number 5728
# DEBUG:MyLogger:This is log message number 5729
# DEBUG:MyLogger:This is log message number 5730
# DEBUG:MyLogger:This is log message number 5731
# DEBUG:MyLogger:This is log message number 5732
# DEBUG:MyLogger:This is log message number 5733
# DEBUG:MyLogger:This is log message number 5734
# DEBUG:MyLogger:This is log message number 5735
# DEBUG:MyLogger:This is log message number 5736
# DEBUG:MyLogger:This is log message number 5737
# DEBUG:MyLogger:This is log message number 5738
# DEBUG:MyLogger:This is log message number 5739
# DEBUG:MyLogger:This is log message number 5740
# DEBUG:MyLogger:This is log message number 5741
# DEBUG:MyLogger:This is log message number 5742
# DEBUG:MyLogger:This is log message number 5743
# DEBUG:MyLogger:This is log message number 5744
# DEBUG:MyLogger:This is log message number 5745
# DEBUG:MyLogger:This is log message number 5746
# DEBUG:MyLogger:This is log message number 5747
# DEBUG:MyLogger:This is log message number 5748
# DEBUG:MyLogger:This is log message number 5749
# DEBUG:MyLogger:This is log message number 5750
# DEBUG:MyLogger:This is log message number 5751
# DEBUG:MyLogger:This is log message number 5752
# DEBUG:MyLogger:This is log message number 5753
# DEBUG:MyLogger:This is log message number 5754
# DEBUG:MyLogger:This is log message number 5755
# DEBUG:MyLogger:This is log message number 5756
# DEBUG:MyLogger:This is log message number 5757
# DEBUG:MyLogger:This is log message number 5758
# DEBUG:MyLogger:This is log message number 5759
# DEBUG:MyLogger:This is log message number 5760
# DEBUG:MyLogger:This is log message number 5761
# DEBUG:MyLogger:This is log message number 5762
# DEBUG:MyLogger:This is log message number 5763
# DEBUG:MyLogger:This is log message number 5764
# DEBUG:MyLogger:This is log message number 5765
# DEBUG:MyLogger:This is log message number 5766
# DEBUG:MyLogger:This is log message number 5767
# DEBUG:MyLogger:This is log message number 5768
# DEBUG:MyLogger:This is log message number 5769
# DEBUG:MyLogger:This is log message number 5770
# DEBUG:MyLogger:This is log message number 5771
# DEBUG:MyLogger:This is log message number 5772
# DEBUG:MyLogger:This is log message number 5773
# DEBUG:MyLogger:This is log message number 5774
# DEBUG:MyLogger:This is log message number 5775
# DEBUG:MyLogger:This is log message number 5776
# DEBUG:MyLogger:This is log message number 5777
# DEBUG:MyLogger:This is log message number 5778
# DEBUG:MyLogger:This is log message number 5779
# DEBUG:MyLogger:This is log message number 5780
# DEBUG:MyLogger:This is log message number 5781
# DEBUG:MyLogger:This is log message number 5782
# DEBUG:MyLogger:This is log message number 5783
# DEBUG:MyLogger:This is log message number 5784
# DEBUG:MyLogger:This is log message number 5785
# DEBUG:MyLogger:This is log message number 5786
# DEBUG:MyLogger:This is log message number 5787
# DEBUG:MyLogger:This is log message number 5788
# DEBUG:MyLogger:This is log message number 5789
# DEBUG:MyLogger:This is log message number 5790
# DEBUG:MyLogger:This is log message number 5791
# DEBUG:MyLogger:This is log message number 5792
# DEBUG:MyLogger:This is log message number 5793
# DEBUG:MyLogger:This is log message number 5794
# DEBUG:MyLogger:This is log message number 5795
# DEBUG:MyLogger:This is log message number 5796
# DEBUG:MyLogger:This is log message number 5797
# DEBUG:MyLogger:This is log message number 5798
# DEBUG:MyLogger:This is log message number 5799
# DEBUG:MyLogger:This is log message number 5800
# DEBUG:MyLogger:This is log message number 5801
# DEBUG:MyLogger:This is log message number 5802
# DEBUG:MyLogger:This is log message number 5803
# DEBUG:MyLogger:This is log message number 5804
# DEBUG:MyLogger:This is log message number 5805
# DEBUG:MyLogger:This is log message number 5806
# DEBUG:MyLogger:This is log message number 5807
# DEBUG:MyLogger:This is log message number 5808
# DEBUG:MyLogger:This is log message number 5809
# DEBUG:MyLogger:This is log message number 5810
# DEBUG:MyLogger:This is log message number 5811
# DEBUG:MyLogger:This is log message number 5812
# DEBUG:MyLogger:This is log message number 5813
# DEBUG:MyLogger:This is log message number 5814
# DEBUG:MyLogger:This is log message number 5815
# DEBUG:MyLogger:This is log message number 5816
# DEBUG:MyLogger:This is log message number 5817
# DEBUG:MyLogger:This is log message number 5818
# DEBUG:MyLogger:This is log message number 5819
# DEBUG:MyLogger:This is log message number 5820
# DEBUG:MyLogger:This is log message number 5821
# DEBUG:MyLogger:This is log message number 5822
# DEBUG:MyLogger:This is log message number 5823
# DEBUG:MyLogger:This is log message number 5824
# DEBUG:MyLogger:This is log message number 5825
# DEBUG:MyLogger:This is log message number 5826
# DEBUG:MyLogger:This is log message number 5827
# DEBUG:MyLogger:This is log message number 5828
# DEBUG:MyLogger:This is log message number 5829
# DEBUG:MyLogger:This is log message number 5830
# DEBUG:MyLogger:This is log message number 5831
# DEBUG:MyLogger:This is log message number 5832
# DEBUG:MyLogger:This is log message number 5833
# DEBUG:MyLogger:This is log message number 5834
# DEBUG:MyLogger:This is log message number 5835
# DEBUG:MyLogger:This is log message number 5836
# DEBUG:MyLogger:This is log message number 5837
# DEBUG:MyLogger:This is log message number 5838
# DEBUG:MyLogger:This is log message number 5839
# DEBUG:MyLogger:This is log message number 5840
# DEBUG:MyLogger:This is log message number 5841
# DEBUG:MyLogger:This is log message number 5842
# DEBUG:MyLogger:This is log message number 5843
# DEBUG:MyLogger:This is log message number 5844
# DEBUG:MyLogger:This is log message number 5845
# DEBUG:MyLogger:This is log message number 5846
# DEBUG:MyLogger:This is log message number 5847
# DEBUG:MyLogger:This is log message number 5848
# DEBUG:MyLogger:This is log message number 5849
# DEBUG:MyLogger:This is log message number 5850
# DEBUG:MyLogger:This is log message number 5851
# DEBUG:MyLogger:This is log message number 5852
# DEBUG:MyLogger:This is log message number 5853
# DEBUG:MyLogger:This is log message number 5854
# DEBUG:MyLogger:This is log message number 5855
# DEBUG:MyLogger:This is log message number 5856
# DEBUG:MyLogger:This is log message number 5857
# DEBUG:MyLogger:This is log message number 5858
# DEBUG:MyLogger:This is log message number 5859
# DEBUG:MyLogger:This is log message number 5860
# DEBUG:MyLogger:This is log message number 5861
# DEBUG:MyLogger:This is log message number 5862
# DEBUG:MyLogger:This is log message number 5863
# DEBUG:MyLogger:This is log message number 5864
# DEBUG:MyLogger:This is log message number 5865
# DEBUG:MyLogger:This is log message number 5866
# DEBUG:MyLogger:This is log message number 5867
# DEBUG:MyLogger:This is log message number 5868
# DEBUG:MyLogger:This is log message number 5869
# DEBUG:MyLogger:This is log message number 5870
# DEBUG:MyLogger:This is log message number 5871
# DEBUG:MyLogger:This is log message number 5872
# DEBUG:MyLogger:This is log message number 5873
# DEBUG:MyLogger:This is log message number 5874
# DEBUG:MyLogger:This is log message number 5875
# DEBUG:MyLogger:This is log message number 5876
# DEBUG:MyLogger:This is log message number 5877
# DEBUG:MyLogger:This is log message number 5878
# DEBUG:MyLogger:This is log message number 5879
# DEBUG:MyLogger:This is log message number 5880
# DEBUG:MyLogger:This is log message number 5881
# DEBUG:MyLogger:This is log message number 5882
# DEBUG:MyLogger:This is log message number 5883
# DEBUG:MyLogger:This is log message number 5884
# DEBUG:MyLogger:This is log message number 5885
# DEBUG:MyLogger:This is log message number 5886
# DEBUG:MyLogger:This is log message number 5887
# DEBUG:MyLogger:This is log message number 5888
# DEBUG:MyLogger:This is log message number 5889
# DEBUG:MyLogger:This is log message number 5890
# DEBUG:MyLogger:This is log message number 5891
# DEBUG:MyLogger:This is log message number 5892
# DEBUG:MyLogger:This is log message number 5893
# DEBUG:MyLogger:This is log message number 5894
# DEBUG:MyLogger:This is log message number 5895
# DEBUG:MyLogger:This is log message number 5896
# DEBUG:MyLogger:This is log message number 5897
# DEBUG:MyLogger:This is log message number 5898
# DEBUG:MyLogger:This is log message number 5899
# DEBUG:MyLogger:This is log message number 5900
# DEBUG:MyLogger:This is log message number 5901
# DEBUG:MyLogger:This is log message number 5902
# DEBUG:MyLogger:This is log message number 5903
# DEBUG:MyLogger:This is log message number 5904
# DEBUG:MyLogger:This is log message number 5905
# DEBUG:MyLogger:This is log message number 5906
# DEBUG:MyLogger:This is log message number 5907
# DEBUG:MyLogger:This is log message number 5908
# DEBUG:MyLogger:This is log message number 5909
# DEBUG:MyLogger:This is log message number 5910
# DEBUG:MyLogger:This is log message number 5911
# DEBUG:MyLogger:This is log message number 5912
# DEBUG:MyLogger:This is log message number 5913
# DEBUG:MyLogger:This is log message number 5914
# DEBUG:MyLogger:This is log message number 5915
# DEBUG:MyLogger:This is log message number 5916
# DEBUG:MyLogger:This is log message number 5917
# DEBUG:MyLogger:This is log message number 5918
# DEBUG:MyLogger:This is log message number 5919
# DEBUG:MyLogger:This is log message number 5920
# DEBUG:MyLogger:This is log message number 5921
# DEBUG:MyLogger:This is log message number 5922
# DEBUG:MyLogger:This is log message number 5923
# DEBUG:MyLogger:This is log message number 5924
# DEBUG:MyLogger:This is log message number 5925
# DEBUG:MyLogger:This is log message number 5926
# DEBUG:MyLogger:This is log message number 5927
# DEBUG:MyLogger:This is log message number 5928
# DEBUG:MyLogger:This is log message number 5929
# DEBUG:MyLogger:This is log message number 5930
# DEBUG:MyLogger:This is log message number 5931
# DEBUG:MyLogger:This is log message number 5932
# DEBUG:MyLogger:This is log message number 5933
# DEBUG:MyLogger:This is log message number 5934
# DEBUG:MyLogger:This is log message number 5935
# DEBUG:MyLogger:This is log message number 5936
# DEBUG:MyLogger:This is log message number 5937
# DEBUG:MyLogger:This is log message number 5938
# DEBUG:MyLogger:This is log message number 5939
# DEBUG:MyLogger:This is log message number 5940
# DEBUG:MyLogger:This is log message number 5941
# DEBUG:MyLogger:This is log message number 5942
# DEBUG:MyLogger:This is log message number 5943
# DEBUG:MyLogger:This is log message number 5944
# DEBUG:MyLogger:This is log message number 5945
# DEBUG:MyLogger:This is log message number 5946
# DEBUG:MyLogger:This is log message number 5947
# DEBUG:MyLogger:This is log message number 5948
# DEBUG:MyLogger:This is log message number 5949
# DEBUG:MyLogger:This is log message number 5950
# DEBUG:MyLogger:This is log message number 5951
# DEBUG:MyLogger:This is log message number 5952
# DEBUG:MyLogger:This is log message number 5953
# DEBUG:MyLogger:This is log message number 5954
# DEBUG:MyLogger:This is log message number 5955
# DEBUG:MyLogger:This is log message number 5956
# DEBUG:MyLogger:This is log message number 5957
# DEBUG:MyLogger:This is log message number 5958
# DEBUG:MyLogger:This is log message number 5959
# DEBUG:MyLogger:This is log message number 5960
# DEBUG:MyLogger:This is log message number 5961
# DEBUG:MyLogger:This is log message number 5962
# DEBUG:MyLogger:This is log message number 5963
# DEBUG:MyLogger:This is log message number 5964
# DEBUG:MyLogger:This is log message number 5965
# DEBUG:MyLogger:This is log message number 5966
# DEBUG:MyLogger:This is log message number 5967
# DEBUG:MyLogger:This is log message number 5968
# DEBUG:MyLogger:This is log message number 5969
# DEBUG:MyLogger:This is log message number 5970
# DEBUG:MyLogger:This is log message number 5971
# DEBUG:MyLogger:This is log message number 5972
# DEBUG:MyLogger:This is log message number 5973
# DEBUG:MyLogger:This is log message number 5974
# DEBUG:MyLogger:This is log message number 5975
# DEBUG:MyLogger:This is log message number 5976
# DEBUG:MyLogger:This is log message number 5977
# DEBUG:MyLogger:This is log message number 5978
# DEBUG:MyLogger:This is log message number 5979
# DEBUG:MyLogger:This is log message number 5980
# DEBUG:MyLogger:This is log message number 5981
# DEBUG:MyLogger:This is log message number 5982
# DEBUG:MyLogger:This is log message number 5983
# DEBUG:MyLogger:This is log message number 5984
# DEBUG:MyLogger:This is log message number 5985
# DEBUG:MyLogger:This is log message number 5986
# DEBUG:MyLogger:This is log message number 5987
# DEBUG:MyLogger:This is log message number 5988
# DEBUG:MyLogger:This is log message number 5989
# DEBUG:MyLogger:This is log message number 5990
# DEBUG:MyLogger:This is log message number 5991
# DEBUG:MyLogger:This is log message number 5992
# DEBUG:MyLogger:This is log message number 5993
# DEBUG:MyLogger:This is log message number 5994
# DEBUG:MyLogger:This is log message number 5995
# DEBUG:MyLogger:This is log message number 5996
# DEBUG:MyLogger:This is log message number 5997
# DEBUG:MyLogger:This is log message number 5998
# DEBUG:MyLogger:This is log message number 5999
# DEBUG:MyLogger:This is log message number 6000
# DEBUG:MyLogger:This is log message number 6001
# DEBUG:MyLogger:This is log message number 6002
# DEBUG:MyLogger:This is log message number 6003
# DEBUG:MyLogger:This is log message number 6004
# DEBUG:MyLogger:This is log message number 6005
# DEBUG:MyLogger:This is log message number 6006
# DEBUG:MyLogger:This is log message number 6007
# DEBUG:MyLogger:This is log message number 6008
# DEBUG:MyLogger:This is log message number 6009
# DEBUG:MyLogger:This is log message number 6010
# DEBUG:MyLogger:This is log message number 6011
# DEBUG:MyLogger:This is log message number 6012
# DEBUG:MyLogger:This is log message number 6013
# DEBUG:MyLogger:This is log message number 6014
# DEBUG:MyLogger:This is log message number 6015
# DEBUG:MyLogger:This is log message number 6016
# DEBUG:MyLogger:This is log message number 6017
# DEBUG:MyLogger:This is log message number 6018
# DEBUG:MyLogger:This is log message number 6019
# ...
# DEBUG:MyLogger:This is log message number 9660
# DEBUG:MyLogger:This is log message number 9661
# DEBUG:MyLogger:This is log message number 9662
# DEBUG:MyLogger:This is log message number 9663
# DEBUG:MyLogger:This is log message number 9664
# DEBUG:MyLogger:This is log message number 9665
# DEBUG:MyLogger:This is log message number 9666
# DEBUG:MyLogger:This is log message number 9667
# DEBUG:MyLogger:This is log message number 9668
# DEBUG:MyLogger:This is log message number 9669
# DEBUG:MyLogger:This is log message number 9670
# DEBUG:MyLogger:This is log message number 9671
# DEBUG:MyLogger:This is log message number 9672
# DEBUG:MyLogger:This is log message number 9673
# DEBUG:MyLogger:This is log message number 9674
# DEBUG:MyLogger:This is log message number 9675
# DEBUG:MyLogger:This is log message number 9676
# DEBUG:MyLogger:This is log message number 9677
# DEBUG:MyLogger:This is log message number 9678
# DEBUG:MyLogger:This is log message number 9679
# DEBUG:MyLogger:This is log message number 9680
# DEBUG:MyLogger:This is log message number 9681
# DEBUG:MyLogger:This is log message number 9682
# DEBUG:MyLogger:This is log message number 9683
# DEBUG:MyLogger:This is log message number 9684
# DEBUG:MyLogger:This is log message number 9685
# DEBUG:MyLogger:This is log message number 9686
# DEBUG:MyLogger:This is log message number 9687
# DEBUG:MyLogger:This is log message number 9688
# DEBUG:MyLogger:This is log message number 9689
# DEBUG:MyLogger:This is log message number 9690
# DEBUG:MyLogger:This is log message number 9691
# DEBUG:MyLogger:This is log message number 9692
# DEBUG:MyLogger:This is log message number 9693
# DEBUG:MyLogger:This is log message number 9694
# DEBUG:MyLogger:This is log message number 9695
# DEBUG:MyLogger:This is log message number 9696
# DEBUG:MyLogger:This is log message number 9697
# DEBUG:MyLogger:This is log message number 9698
# DEBUG:MyLogger:This is log message number 9699
# DEBUG:MyLogger:This is log message number 9700
# DEBUG:MyLogger:This is log message number 9701
# DEBUG:MyLogger:This is log message number 9702
# DEBUG:MyLogger:This is log message number 9703
# DEBUG:MyLogger:This is log message number 9704
# DEBUG:MyLogger:This is log message number 9705
# DEBUG:MyLogger:This is log message number 9706
# DEBUG:MyLogger:This is log message number 9707
# DEBUG:MyLogger:This is log message number 9708
# DEBUG:MyLogger:This is log message number 9709
# DEBUG:MyLogger:This is log message number 9710
# DEBUG:MyLogger:This is log message number 9711
# DEBUG:MyLogger:This is log message number 9712
# DEBUG:MyLogger:This is log message number 9713
# DEBUG:MyLogger:This is log message number 9714
# DEBUG:MyLogger:This is log message number 9715
# DEBUG:MyLogger:This is log message number 9716
# DEBUG:MyLogger:This is log message number 9717
# DEBUG:MyLogger:This is log message number 9718
# DEBUG:MyLogger:This is log message number 9719
# DEBUG:MyLogger:This is log message number 9720
# DEBUG:MyLogger:This is log message number 9721
# DEBUG:MyLogger:This is log message number 9722
# DEBUG:MyLogger:This is log message number 9723
# DEBUG:MyLogger:This is log message number 9724
# DEBUG:MyLogger:This is log message number 9725
# DEBUG:MyLogger:This is log message number 9726
# DEBUG:MyLogger:This is log message number 9727
# DEBUG:MyLogger:This is log message number 9728
# DEBUG:MyLogger:This is log message number 9729
# DEBUG:MyLogger:This is log message number 9730
# DEBUG:MyLogger:This is log message number 9731
# DEBUG:MyLogger:This is log message number 9732
# DEBUG:MyLogger:This is log message number 9733
# DEBUG:MyLogger:This is log message number 9734
# DEBUG:MyLogger:This is log message number 9735
# DEBUG:MyLogger:This is log message number 9736
# DEBUG:MyLogger:This is log message number 9737
# DEBUG:MyLogger:This is log message number 9738
# DEBUG:MyLogger:This is log message number 9739
# DEBUG:MyLogger:This is log message number 9740
# DEBUG:MyLogger:This is log message number 9741
# DEBUG:MyLogger:This is log message number 9742
# DEBUG:MyLogger:This is log message number 9743
# DEBUG:MyLogger:This is log message number 9744
# DEBUG:MyLogger:This is log message number 9745
# DEBUG:MyLogger:This is log message number 9746
# DEBUG:MyLogger:This is log message number 9747
# DEBUG:MyLogger:This is log message number 9748
# DEBUG:MyLogger:This is log message number 9749
# DEBUG:MyLogger:This is log message number 9750
# DEBUG:MyLogger:This is log message number 9751
# DEBUG:MyLogger:This is log message number 9752
# DEBUG:MyLogger:This is log message number 9753
# DEBUG:MyLogger:This is log message number 9754
# DEBUG:MyLogger:This is log message number 9755
# DEBUG:MyLogger:This is log message number 9756
# DEBUG:MyLogger:This is log message number 9757
# DEBUG:MyLogger:This is log message number 9758
# DEBUG:MyLogger:This is log message number 9759
# DEBUG:MyLogger:This is log message number 9760
# DEBUG:MyLogger:This is log message number 9761
# DEBUG:MyLogger:This is log message number 9762
# DEBUG:MyLogger:This is log message number 9763
# DEBUG:MyLogger:This is log message number 9764
# DEBUG:MyLogger:This is log message number 9765
# DEBUG:MyLogger:This is log message number 9766
# DEBUG:MyLogger:This is log message number 9767
# DEBUG:MyLogger:This is log message number 9768
# DEBUG:MyLogger:This is log message number 9769
# DEBUG:MyLogger:This is log message number 9770
# DEBUG:MyLogger:This is log message number 9771
# DEBUG:MyLogger:This is log message number 9772
# DEBUG:MyLogger:This is log message number 9773
# DEBUG:MyLogger:This is log message number 9774
# DEBUG:MyLogger:This is log message number 9775
# DEBUG:MyLogger:This is log message number 9776
# DEBUG:MyLogger:This is log message number 9777
# DEBUG:MyLogger:This is log message number 9778
# DEBUG:MyLogger:This is log message number 9779
# DEBUG:MyLogger:This is log message number 9780
# DEBUG:MyLogger:This is log message number 9781
# DEBUG:MyLogger:This is log message number 9782
# DEBUG:MyLogger:This is log message number 9783
# DEBUG:MyLogger:This is log message number 9784
# DEBUG:MyLogger:This is log message number 9785
# DEBUG:MyLogger:This is log message number 9786
# DEBUG:MyLogger:This is log message number 9787
# DEBUG:MyLogger:This is log message number 9788
# DEBUG:MyLogger:This is log message number 9789
# DEBUG:MyLogger:This is log message number 9790
# DEBUG:MyLogger:This is log message number 9791
# DEBUG:MyLogger:This is log message number 9792
# DEBUG:MyLogger:This is log message number 9793
# DEBUG:MyLogger:This is log message number 9794
# DEBUG:MyLogger:This is log message number 9795
# DEBUG:MyLogger:This is log message number 9796
# DEBUG:MyLogger:This is log message number 9797
# DEBUG:MyLogger:This is log message number 9798
# DEBUG:MyLogger:This is log message number 9799
# DEBUG:MyLogger:This is log message number 9800
# DEBUG:MyLogger:This is log message number 9801
# DEBUG:MyLogger:This is log message number 9802
# DEBUG:MyLogger:This is log message number 9803
# DEBUG:MyLogger:This is log message number 9804
# DEBUG:MyLogger:This is log message number 9805
# DEBUG:MyLogger:This is log message number 9806
# DEBUG:MyLogger:This is log message number 9807
# DEBUG:MyLogger:This is log message number 9808
# DEBUG:MyLogger:This is log message number 9809
# DEBUG:MyLogger:This is log message number 9810
# DEBUG:MyLogger:This is log message number 9811
# DEBUG:MyLogger:This is log message number 9812
# DEBUG:MyLogger:This is log message number 9813
# DEBUG:MyLogger:This is log message number 9814
# DEBUG:MyLogger:This is log message number 9815
# DEBUG:MyLogger:This is log message number 9816
# DEBUG:MyLogger:This is log message number 9817
# DEBUG:MyLogger:This is log message number 9818
# DEBUG:MyLogger:This is log message number 9819
# DEBUG:MyLogger:This is log message number 9820
# DEBUG:MyLogger:This is log message number 9821
# DEBUG:MyLogger:This is log message number 9822
# DEBUG:MyLogger:This is log message number 9823
# DEBUG:MyLogger:This is log message number 9824
# DEBUG:MyLogger:This is log message number 9825
# DEBUG:MyLogger:This is log message number 9826
# DEBUG:MyLogger:This is log message number 9827
# DEBUG:MyLogger:This is log message number 9828
# DEBUG:MyLogger:This is log message number 9829
# DEBUG:MyLogger:This is log message number 9830
# DEBUG:MyLogger:This is log message number 9831
# DEBUG:MyLogger:This is log message number 9832
# DEBUG:MyLogger:This is log message number 9833
# DEBUG:MyLogger:This is log message number 9834
# DEBUG:MyLogger:This is log message number 9835
# DEBUG:MyLogger:This is log message number 9836
# DEBUG:MyLogger:This is log message number 9837
# DEBUG:MyLogger:This is log message number 9838
# DEBUG:MyLogger:This is log message number 9839
# DEBUG:MyLogger:This is log message number 9840
# DEBUG:MyLogger:This is log message number 9841
# DEBUG:MyLogger:This is log message number 9842
# DEBUG:MyLogger:This is log message number 9843
# DEBUG:MyLogger:This is log message number 9844
# DEBUG:MyLogger:This is log message number 9845
# DEBUG:MyLogger:This is log message number 9846
# DEBUG:MyLogger:This is log message number 9847
# DEBUG:MyLogger:This is log message number 9848
# DEBUG:MyLogger:This is log message number 9849
# DEBUG:MyLogger:This is log message number 9850
# DEBUG:MyLogger:This is log message number 9851
# DEBUG:MyLogger:This is log message number 9852
# DEBUG:MyLogger:This is log message number 9853
# DEBUG:MyLogger:This is log message number 9854
# DEBUG:MyLogger:This is log message number 9855
# DEBUG:MyLogger:This is log message number 9856
# DEBUG:MyLogger:This is log message number 9857
# DEBUG:MyLogger:This is log message number 9858
# DEBUG:MyLogger:This is log message number 9859
# DEBUG:MyLogger:This is log message number 9860
# DEBUG:MyLogger:This is log message number 9861
# DEBUG:MyLogger:This is log message number 9862
# DEBUG:MyLogger:This is log message number 9863
# DEBUG:MyLogger:This is log message number 9864
# DEBUG:MyLogger:This is log message number 9865
# DEBUG:MyLogger:This is log message number 9866
# DEBUG:MyLogger:This is log message number 9867
# DEBUG:MyLogger:This is log message number 9868
# DEBUG:MyLogger:This is log message number 9869
# DEBUG:MyLogger:This is log message number 9870
# DEBUG:MyLogger:This is log message number 9871
# DEBUG:MyLogger:This is log message number 9872
# DEBUG:MyLogger:This is log message number 9873
# DEBUG:MyLogger:This is log message number 9874
# DEBUG:MyLogger:This is log message number 9875
# DEBUG:MyLogger:This is log message number 9876
# DEBUG:MyLogger:This is log message number 9877
# DEBUG:MyLogger:This is log message number 9878
# DEBUG:MyLogger:This is log message number 9879
# DEBUG:MyLogger:This is log message number 9880
# DEBUG:MyLogger:This is log message number 9881
# DEBUG:MyLogger:This is log message number 9882
# DEBUG:MyLogger:This is log message number 9883
# DEBUG:MyLogger:This is log message number 9884
# DEBUG:MyLogger:This is log message number 9885
# DEBUG:MyLogger:This is log message number 9886
# DEBUG:MyLogger:This is log message number 9887
# DEBUG:MyLogger:This is log message number 9888
# DEBUG:MyLogger:This is log message number 9889
# DEBUG:MyLogger:This is log message number 9890
# DEBUG:MyLogger:This is log message number 9891
# DEBUG:MyLogger:This is log message number 9892
# DEBUG:MyLogger:This is log message number 9893
# DEBUG:MyLogger:This is log message number 9894
# DEBUG:MyLogger:This is log message number 9895
# DEBUG:MyLogger:This is log message number 9896
# DEBUG:MyLogger:This is log message number 9897
# DEBUG:MyLogger:This is log message number 9898
# DEBUG:MyLogger:This is log message number 9899
# DEBUG:MyLogger:This is log message number 9900
# DEBUG:MyLogger:This is log message number 9901
# DEBUG:MyLogger:This is log message number 9902
# DEBUG:MyLogger:This is log message number 9903
# DEBUG:MyLogger:This is log message number 9904
# DEBUG:MyLogger:This is log message number 9905
# DEBUG:MyLogger:This is log message number 9906
# DEBUG:MyLogger:This is log message number 9907
# DEBUG:MyLogger:This is log message number 9908
# DEBUG:MyLogger:This is log message number 9909
# DEBUG:MyLogger:This is log message number 9910
# DEBUG:MyLogger:This is log message number 9911
# DEBUG:MyLogger:This is log message number 9912
# DEBUG:MyLogger:This is log message number 9913
# DEBUG:MyLogger:This is log message number 9914
# DEBUG:MyLogger:This is log message number 9915
# DEBUG:MyLogger:This is log message number 9916
# DEBUG:MyLogger:This is log message number 9917
# DEBUG:MyLogger:This is log message number 9918
# DEBUG:MyLogger:This is log message number 9919
# DEBUG:MyLogger:This is log message number 9920
# DEBUG:MyLogger:This is log message number 9921
# DEBUG:MyLogger:This is log message number 9922
# DEBUG:MyLogger:This is log message number 9923
# DEBUG:MyLogger:This is log message number 9924
# DEBUG:MyLogger:This is log message number 9925
# DEBUG:MyLogger:This is log message number 9926
# DEBUG:MyLogger:This is log message number 9927
# DEBUG:MyLogger:This is log message number 9928
# DEBUG:MyLogger:This is log message number 9929
# DEBUG:MyLogger:This is log message number 9930
# DEBUG:MyLogger:This is log message number 9931
# DEBUG:MyLogger:This is log message number 9932
# DEBUG:MyLogger:This is log message number 9933
# DEBUG:MyLogger:This is log message number 9934
# DEBUG:MyLogger:This is log message number 9935
# DEBUG:MyLogger:This is log message number 9936
# DEBUG:MyLogger:This is log message number 9937
# DEBUG:MyLogger:This is log message number 9938
# DEBUG:MyLogger:This is log message number 9939
# DEBUG:MyLogger:This is log message number 9940
# DEBUG:MyLogger:This is log message number 9941
# DEBUG:MyLogger:This is log message number 9942
# DEBUG:MyLogger:This is log message number 9943
# DEBUG:MyLogger:This is log message number 9944
# DEBUG:MyLogger:This is log message number 9945
# DEBUG:MyLogger:This is log message number 9946
# DEBUG:MyLogger:This is log message number 9947
# DEBUG:MyLogger:This is log message number 9948
# DEBUG:MyLogger:This is log message number 9949
# DEBUG:MyLogger:This is log message number 9950
# DEBUG:MyLogger:This is log message number 9951
# DEBUG:MyLogger:This is log message number 9952
# DEBUG:MyLogger:This is log message number 9953
# DEBUG:MyLogger:This is log message number 9954
# DEBUG:MyLogger:This is log message number 9955
# DEBUG:MyLogger:This is log message number 9956
# DEBUG:MyLogger:This is log message number 9957
# DEBUG:MyLogger:This is log message number 9958
# DEBUG:MyLogger:This is log message number 9959
# DEBUG:MyLogger:This is log message number 9960
# DEBUG:MyLogger:This is log message number 9961
# DEBUG:MyLogger:This is log message number 9962
# DEBUG:MyLogger:This is log message number 9963
# DEBUG:MyLogger:This is log message number 9964
# DEBUG:MyLogger:This is log message number 9965
# DEBUG:MyLogger:This is log message number 9966
# DEBUG:MyLogger:This is log message number 9967
# DEBUG:MyLogger:This is log message number 9968
# DEBUG:MyLogger:This is log message number 9969
# DEBUG:MyLogger:This is log message number 9970
# DEBUG:MyLogger:This is log message number 9971
# DEBUG:MyLogger:This is log message number 9972
# DEBUG:MyLogger:This is log message number 9973
# DEBUG:MyLogger:This is log message number 9974
# DEBUG:MyLogger:This is log message number 9975
# DEBUG:MyLogger:This is log message number 9976
# DEBUG:MyLogger:This is log message number 9977
# DEBUG:MyLogger:This is log message number 9978
# DEBUG:MyLogger:This is log message number 9979
# DEBUG:MyLogger:This is log message number 9980
# DEBUG:MyLogger:This is log message number 9981
# DEBUG:MyLogger:This is log message number 9982
# DEBUG:MyLogger:This is log message number 9983
# DEBUG:MyLogger:This is log message number 9984
# DEBUG:MyLogger:This is log message number 9985
# DEBUG:MyLogger:This is log message number 9986
# DEBUG:MyLogger:This is log message number 9987
# DEBUG:MyLogger:This is log message number 9988
# DEBUG:MyLogger:This is log message number 9989
# DEBUG:MyLogger:This is log message number 9990
# DEBUG:MyLogger:This is log message number 9991
# DEBUG:MyLogger:This is log message number 9992
# DEBUG:MyLogger:This is log message number 9993
# DEBUG:MyLogger:This is log message number 9994
# DEBUG:MyLogger:This is log message number 9995
# DEBUG:MyLogger:This is log message number 9996
# DEBUG:MyLogger:This is log message number 9997
# DEBUG:MyLogger:This is log message number 9998
# DEBUG:MyLogger:This is log message number 9999

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block.

# %%
def handle_errors():
    my_list = [10, 20, 30]
    my_dict = {"name": "Alice", "age": 25}

    try:
        # Trying to access an index that doesn't exist
        print("Accessing list element at index 5:", my_list[5])

        # Trying to access a dictionary key that doesn't exist
        print("Accessing dictionary key 'address':", my_dict["address"])

    except IndexError:
        print("Caught an IndexError: List index out of range.")

    except KeyError:
        print("Caught a KeyError: Specified key not found in dictionary.")

# Run the function
handle_errors()
# Out:
# Caught an IndexError: List index out of range.

# %% [markdown]
# 20.  How would you open a file and read its contents using a context manager in Python?

# %% [markdown]
# Hello, Python!
# Welcome to file handling using a context manager.
# Have a great day!

# %%
with open("/content/LINE.TEX.txt", "r") as file:
    content = file.read()
    print("File Contents:\n")
    print(content)
# Out:
# File Contents:
#
# Line 1: Hello
# Line 2: Welcome to Python
# Line 3: File reading exampleThis is a new line being appended.
# This is a new line being appended.
# Line 3: Python is great
# Line 4: File handling is easy

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
# Specify the file and word to search for
filename = "/content/LINE.TEX.txt"
search_word = "python"

try:
    with open(filename, "r") as file:
        content = file.read().lower()  # Convert to lowercase for case-insensitive search

    # Count the word occurrences
    word_count = content.split().count(search_word)

    print(f"The word '{search_word}' occurs {word_count} time(s) in '{filename}'.")

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# The word 'python' occurs 2 time(s) in '/content/LINE.TEX.txt'.

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents?

# %%
import os

file_path = "example.txt"

if os.path.exists(file_path) and os.path.getsize(file_path) > 0:
    with open(file_path, 'r') as f:
        content = f.read()
        print("File Content:\n", content)
else:
    print("The file is empty or does not exist.")
# Out:
# The file is empty or does not exist.

# %% [markdown]
# 23.  Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

logging.basicConfig(
    filename='error_log.txt',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def read_file(filename):
    try:
        with open(filename, 'r') as f:
            content = f.read()
            print("File content:\n", content)
    except Exception as e:
        logging.error("Failed to open file '%s': %s", filename, e)
        print(f"An error occurred while reading the file. Check 'error_log.txt' for details.")

read_file("/content/destination.txt")
# Out:
# File content:
#  Line 1: Hello
# Line 2: Welcome to Python
# Line 3: File reading example

# %%
import logging

# Configure logging to write errors to a log file
logging.basicConfig(
    filename="file_errors.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

filename = "missing_file.txt"

try:
    # Attempt to open a non-existent file
    with open(filename, "r") as file:
        content = file.read()
        print(content)

except FileNotFoundError as e:
    # Log the error to file_errors.log
    logging.error(f"File not found: {filename} - {e}")
    print(f"Error: Could not open the file '{filename}'. Error has been logged.")

except Exception as e:
    # Log any other file handling error
    logging.error(f"An unexpected error occurred: {e}")
    print("An unexpected error occurred. See 'file_errors.log' for details.")
# Out:
# ERROR:root:File not found: missing_file.txt - [Errno 2] No such file or directory: 'missing_file.txt'
# Error: Could not open the file 'missing_file.txt'. Error has been logged.

# %%
# !pip install memory-profiler
# Out:
# Collecting memory-profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory-profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0
